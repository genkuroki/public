# %%
f(x) = tand(x) / x
for k in  0:8
    x = parse(Float64, "1e-$k")
    @eval @show f($x)
end
@show π/180;
# Out:
# f(1.0) = 0.017455064928217585
# f(0.1) = 0.017453310241888006
# f(0.01) = 0.017453292697162528
# f(0.001) = 0.017453292521715486
# f(0.0001) = 0.01745329251996102
# f(1.0e-5) = 0.017453292519943472
# f(1.0e-6) = 0.0174532925199433
# f(1.0e-7) = 0.017453292519943295
# f(1.0e-8) = 0.017453292519943295
# π / 180 = 0.017453292519943295

# %%
using LinearAlgebra
using SymPy
@vars s t u λ
# Out:
# (s, t, u, λ)

# %%
A(x) = Sym[
    cos(x) -sin(x) 0
    sin(x)  cos(x) 0
    0 0 1
]

B(x) = Sym[
    1 0 0
    0 cos(x) -sin(x)
    0 sin(x)  cos(x)
]

X = A(s)*B(t)*A(u)
# Out:
# 3×3 Matrix{Sym}:
#  -sin(s)*sin(u)*cos(t) + cos(s)*cos(u)  …   sin(s)*sin(t)
#   sin(s)*cos(u) + sin(u)*cos(s)*cos(t)     -sin(t)*cos(s)
#                          sin(t)*sin(u)             cos(t)

# %%
det(X - I).simplify()
# Out:
# 0

# %%
p = det(λ*I - X).simplify()
# Out:
#  3    2                      2           2
# λ  - λ *cos(t)*cos(s + u) - λ *cos(t) - λ *cos(s + u) + λ*cos(t)*cos(s + u) +
#
#
# λ*cos(t) + λ*cos(s + u) - 1

# %%
sympy.Poly(p, λ)
# Out:
# Poly(λ**3 + (-cos(t)*cos(s + u) - cos(t) - cos(s + u))*λ**2 + (cos(t)*cos(s +
# u) + cos(t) + cos(s + u))*λ - 1, λ, domain='ZZ[cos(s + u),cos(t)]')

# %%
1
# Out:
# 1

# %%
using Plots
default(fmt=:png)

f(q, z; N=100) = sum(q^n^2 * z^n for n in -N:N)
g(q, z; N=100) = prod((1 - q^2n) * (1 + q^(2n-1)*z) * (1 + q^(2n-1)/z) for n in 1:N)

q = 0.3
z = 0.5
@eval @show f($q, $z) g($q, $z)

plot(z -> f(q, z), 0.1, 10; label="f($q, z)")
plot!(z -> g(q, z), 0.1, 10; label="g($q, z)", ls=:dash)
plot!(xguide="z")
# Out:
# f(0.3, 0.5) = 1.7845849935215092
# g(0.3, 0.5) = 1.7845849935215095

# %%
plot!(xscale=:log10)
_tick = Any[0.1, 0.2, 0.5, 1, 2, 5, 10]
xtick = (float.(_tick), string.(_tick))
plot!(; xtick)

# %%
plot(z -> f(q, z), -10, -0.1; label="f($q, z)")
plot!(z -> g(q, z), -10, -0.1; label="g($q, z)", ls=:dash)
plot!(xguide="z")

# %%
a, b = [1 2; 3 4; 5 6]
a, b
# Out:
# (1, 3)
