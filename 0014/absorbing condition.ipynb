# %%
using Plots
using LinearAlgebra
using Fmt

# %%
f(a) = -a + √(a^2 - 2)
a = range(√2, 100, 1000)
plot(a, f; ylim=(-1.5, 0), label="")

# %%
A(a) = Float64[
     0  1
    -2 -2a
]

U(a, t) = exp(t*A(a))
# Out:
# U (generic function with 1 method)

# %%
@gif for a in [0:0.02:1.4; fill(1.4, 40); 1.4:0.04:5]
    t = range(0, 4π; length=1000)
    u = (t -> U(a, t)[1, 1]).(t)
    v = (t -> U(a, t)[2, 1]).(t)
    P = plot(t, [u v]; label=["u1" "v1"], ylim=(-1, 1))
    u = (t -> U(a, t)[1, 2]).(t)
    v = (t -> U(a, t)[2, 2]).(t)
    plot!(t, [u v]; label=["u2" "v2"], ylim=(-1, 1), ls=:dash)
    plot!(; title=f"a = {$a:.2f}")
end
# Out:
# ┌ Info: Saved animation to
# │   fn = D:\OneDrive\public\0014\tmp.gif
# └ @ Plots D:\.julia\packages\Plots\avj9X\src\animation.jl:104
# Plots.AnimatedGif("D:\\OneDrive\\public\\0014\\tmp.gif")

# %%
for a in 0.1:0.1:2
    t = reverse(range(0, 10π; length=5001))
    n = accumulate(max, norm.(U.(a, t)))
    k = findfirst(t -> norm(U(a, t)) > 0.1, t)
    @show a, t[k], norm(U(a, t[k]))
end
# Out:
# (a, t[k], norm(U(a, t[k]))) = (0.1, 26.55902429344811, 0.10001736524884426)
# (a, t[k], norm(U(a, t[k]))) = (0.2, 13.288936924684824, 0.10000043843877501)
# (a, t[k], norm(U(a, t[k]))) = (0.3, 8.878140839044756, 0.10006898407731744)
# (a, t[k], norm(U(a, t[k]))) = (0.4, 6.68530916683908, 0.10014488748427651)
# (a, t[k], norm(U(a, t[k]))) = (0.5, 5.717698629533423, 0.10011918840639907)
# (a, t[k], norm(U(a, t[k]))) = (0.6, 4.5301766064764815, 0.10051398454173838)
# (a, t[k], norm(U(a, t[k]))) = (0.7, 4.197167785195964, 0.10045962465646882)
# (a, t[k], norm(U(a, t[k]))) = (0.8, 3.807610296150829, 0.10005528857565493)
# (a, t[k], norm(U(a, t[k]))) = (0.9, 2.946813909067226, 0.10017440185438616)
# (a, t[k], norm(U(a, t[k]))) = (1.0, 2.777167905773377, 0.10099357319196438)
# (a, t[k], norm(U(a, t[k]))) = (1.1, 2.796017461694916, 0.10064176387308531)
# (a, t[k], norm(U(a, t[k]))) = (1.2, 2.8902652413026098, 0.10009034452300768)
# (a, t[k], norm(U(a, t[k]))) = (1.3, 3.0284953180605605, 0.10079113062982245)
# (a, t[k], norm(U(a, t[k]))) = (1.4, 3.2107076919687687, 0.10065141859439819)
# (a, t[k], norm(U(a, t[k]))) = (1.5, 3.418052807105695, 0.10060087479865343)
# (a, t[k], norm(U(a, t[k]))) = (1.6, 3.64424747816416, 0.10019694304744894)
# (a, t[k], norm(U(a, t[k]))) = (1.7, 3.870442149222625, 0.10041052236605434)
# (a, t[k], norm(U(a, t[k]))) = (1.8, 4.1029200055882695, 0.10034793274915894)
# (a, t[k], norm(U(a, t[k]))) = (1.9, 4.335397861953915, 0.10035454057779108)
# (a, t[k], norm(U(a, t[k]))) = (2.0, 4.567875718319559, 0.10036767960832942)

# %%
t = range(0, 4π; length=1000)
u = (t -> U(t)[1, 1]).(t)
v = (t -> U(t)[2, 1]).(t)
plot(t, [u v])

# %%
t = range(0, 10; length=1000)
u = (t -> U(t)[1, 2]).(t)
v = (t -> U(t)[2, 2]).(t)
plot(t, [u v])

# %%
a, V = eigen(A)
# Out:
# Eigen{ComplexF64, ComplexF64, Matrix{ComplexF64}, Vector{ComplexF64}}
# values:
# 2-element Vector{ComplexF64}:
#  -0.9999999999999998 - 0.9999999999999998im
#  -0.9999999999999998 + 0.9999999999999998im
# vectors:
# 2×2 Matrix{ComplexF64}:
#  -0.408248+0.408248im  -0.408248-0.408248im
#   0.816497-0.0im        0.816497+0.0im

# %%
V/0.40824829046386296
# Out:
# 2×2 Matrix{ComplexF64}:
#  -1.0+1.0im  -1.0-1.0im
#   2.0-0.0im   2.0+0.0im

# %%
p = [
    -1 + 1im
    2
]

A*p - (-1 - 1im)*p
# Out:
# 2-element Vector{Complex{Int64}}:
#  0 + 0im
#  0 + 0im

# %%
q = [
    -1 - 1im
    2
]

A*q - (-1 + 1im)*q
# Out:
# 2-element Vector{Complex{Int64}}:
#  0 + 0im
#  0 + 0im

# %%
[minimum(real.(eigvals(Float64[0 1; -2 -2a]))) for a in 0:0.1:2]
# Out:
# 21-element Vector{Float64}:
#  -0.0
#  -0.1
#  -0.2
#  -0.30000000000000004
#  -0.4
#  -0.5
#  -0.6000000000000001
#  -0.7
#  -0.8
#  -0.8999999999999999
#  -0.9999999999999998
#  -1.1
#  -1.2000000000000002
#  -1.2999999999999998
#  -1.4000000000000001
#  -2.0
#  -2.3483314773547885
#  -2.6433981132056603
#  -2.9135528725660045
#  -3.168857754044952
#  -3.414213562373095

# %%
using SymPy

# %%
@vars a
# Out:
# (a,)

# %%
A = [
    0 1
    -2 -2
]
# Out:
# 2×2 Matrix{Int64}:
#   0   1
#  -2  -2

# %%
A^2//2
# Out:
# 2×2 Matrix{Rational{Int64}}:
#  -1//1  -1//1
#   2//1   1//1

# %%
A^3//6
# Out:
# 2×2 Matrix{Rational{Int64}}:
#   2//3  1//3
#  -2//3  0//1

# %%
A^4//24
# Out:
# 2×2 Matrix{Rational{Int64}}:
#  -1//6   0//1
#   0//1  -1//6

# %%
B = [
    0 1
    -2 -2a
]
# Out:
# 2×2 Matrix{Sym}:
#   0     1
#  -2  -2*a

# %%
B^2/factorial(2)
# Out:
# 2×2 Matrix{Sym}:
#   -1         -a
#  2*a  2*a^2 - 1

# %%
expand.(B^3)/factorial(3)
# Out:
# 2×2 Matrix{Sym}:
#          2*a/3     2*a^2/3 - 1/3
#  2/3 - 4*a^2/3  -4*a^3/3 + 4*a/3

# %%
expand.(B^4)/factorial(4)
# Out:
# 2×2 Matrix{Sym}:
#      1/6 - a^2/3         -a^3/3 + a/3
#  2*a^3/3 - 2*a/3  2*a^4/3 - a^2 + 1/6
