# %%
using Distributions

# %% [markdown]
# ![image.jpeg](attachment:ad7f0d3a-c295-4686-b301-d231247e76d9.jpeg)

# %% [markdown]
# 24.3 : (11.7 + 24.3) = z : 1.96

# %%
2ccdf(Normal(), 1.96*24.3/(11.7 + 24.3))
# Out:
# 0.1858353778312751

# %%
2ccdf(Normal(), 1.96*21.0/(21.0 + 7.2))
# Out:
# 0.14440706051120417
