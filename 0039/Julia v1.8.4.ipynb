# %%
versioninfo()
# Out:
# Julia Version 1.8.4
# Commit 00177ebc4f (2022-12-23 21:32 UTC)
# Platform Info:
#   OS: Windows (x86_64-w64-mingw32)
#   CPU: 12 × Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-13.0.1 (ORCJIT, skylake)
#   Threads: 12 on 12 virtual cores
# Environment:
#   JULIA_DEPOT_PATH = D:\.julia
#   JULIA_NUM_PRECOMPILE_TASKS = 4
#   JULIA_NUM_THREADS = 12
#   JULIA_PYTHONCALL_EXE = D:\.julia\conda\3\python.exe

# %%
]st -m Plots GR
# Out:
# Status `D:\.julia\environments\v1.8\Manifest.toml`
#   [28b8d3ca] GR v0.71.3
#   [91a5bcdd] Plots v1.38.1

# %%
@showtime using Plots
# Out:
# using Plots: 5.306090 seconds (9.39 M allocations: 605.716 MiB, 7.01% gc time, 20.81% compilation time: 57% of which was recompilation)

# %%
@showtime P = plot(sin);
# Out:
# P = plot(sin): 3.690912 seconds (8.51 M allocations: 446.264 MiB, 2.91% gc time, 99.86% compilation time: 55% of which was recompilation)

# %%
@showtime display(P)
# Out:
# display(P): 4.435430 seconds (6.68 M allocations: 364.480 MiB, 1.86% gc time, 98.60% compilation time: 32% of which was recompilation)

# %%
@showtime histogram(randn(1000))
# Out:
# histogram(randn(1000)): 1.032699 seconds (1.27 M allocations: 68.269 MiB, 1.32% gc time, 99.38% compilation time: 31% of which was recompilation)
