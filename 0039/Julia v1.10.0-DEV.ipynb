# %%
versioninfo()
# Out:
# Julia Version 1.10.0-DEV.221
# Commit 6740224b94 (2022-12-29 18:13 UTC)
# Platform Info:
#   OS: Windows (x86_64-w64-mingw32)
#   CPU: 12 × Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-14.0.6 (ORCJIT, skylake)
#   Threads: 13 on 12 virtual cores
# Environment:
#   JULIA_DEPOT_PATH = D:\.julia
#   JULIA_NUM_PRECOMPILE_TASKS = 4
#   JULIA_NUM_THREADS = 12
#   JULIA_PYTHONCALL_EXE = D:\.julia\conda\3\python.exe

# %%
]st -m Plots GR
# Out:
# Status `D:\.julia\environments\v1.10\Manifest.toml`
#   [28b8d3ca] GR v0.71.3
#   [91a5bcdd] Plots v1.38.1

# %%
@showtime using Plots
# Out:
# using Plots: 3.480999 seconds (5.48 M allocations: 340.564 MiB, 5.87% gc time, 2.08% compilation time)

# %%
@showtime P = plot(sin);
# Out:
# P = plot(sin): 0.377924 seconds (280.30 k allocations: 17.317 MiB, 98.41% compilation time: 6% of which was recompilation)

# %%
@showtime display(P)
# Out:
# display(P): 0.506459 seconds (320.26 k allocations: 21.203 MiB, 3.22% gc time, 89.71% compilation time)

# %%
@showtime histogram(randn(1000))
# Out:
# histogram(randn(1000)): 0.051728 seconds (18.30 k allocations: 976.433 KiB, 90.20% compilation time)
