# %%
using Plots
default(fmt=:png)

f(x, y) = (x,y)==(0,0) ? zero(x^2*y/(x^2+y^2)) : x^2*y/(x^2+y^2)
x = range(-1, 1, 21)
y = range(-1, 1, 21)
z = f.(x', y)
wireframe(x, y, z)

# %%
wireframe(x, y, f)
