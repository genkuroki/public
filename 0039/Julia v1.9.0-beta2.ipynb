# %%
versioninfo()
# Out:
# Julia Version 1.9.0-beta2
# Commit 7daffeecb8 (2022-12-29 07:45 UTC)
# Platform Info:
#   OS: Windows (x86_64-w64-mingw32)
#   CPU: 12 × Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-14.0.6 (ORCJIT, skylake)
#   Threads: 13 on 12 virtual cores
# Environment:
#   JULIA_DEPOT_PATH = D:\.julia
#   JULIA_NUM_PRECOMPILE_TASKS = 4
#   JULIA_NUM_THREADS = 12
#   JULIA_PYTHONCALL_EXE = D:\.julia\conda\3\python.exe

# %%
]st -m Plots GR
# Out:
# Status `D:\.julia\environments\v1.9\Manifest.toml`
#   [28b8d3ca] GR v0.71.3
#   [91a5bcdd] Plots v1.38.1

# %%
@showtime using Plots
# Out:
# using Plots: 3.577214 seconds (5.86 M allocations: 360.412 MiB, 5.72% gc time, 1.98% compilation time)

# %%
@showtime P = plot(sin);
# Out:
# P = plot(sin): 0.355743 seconds (279.35 k allocations: 17.204 MiB, 113.20% compilation time: 5% of which was recompilation)

# %%
@showtime display(P)
# Out:
# display(P): 0.546290 seconds (324.89 k allocations: 21.579 MiB, 3.36% gc time, 105.11% compilation time)

# %%
@showtime histogram(randn(1000))
# Out:
# histogram(randn(1000)): 0.060817 seconds (20.61 k allocations: 1.115 MiB, 94.94% compilation time)
