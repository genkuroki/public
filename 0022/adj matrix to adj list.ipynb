# %%
using SparseArrays

nzptr(A::SparseArrays.AbstractSparseMatrixCSC, col::Integer) = view(rowvals(A), nzrange(A, col))

using Random, LinearAlgebra
Random.seed!(12345678)

n = 20000
p = 2/n
@time A = Symmetric(sprand(Bool, n, n, p)) # test adjacency matrix
@time B = sparse(A)
@time C = nzptr.(Ref(B), axes(B, 2)) # adjacency list
# Out:
#   0.136609 seconds (378.24 k allocations: 23.257 MiB, 99.43% compilation time)
#   0.088141 seconds (174.50 k allocations: 11.047 MiB, 99.16% compilation time)
#   0.054241 seconds (254.98 k allocations: 16.042 MiB, 99.25% compilation time)
# 20000-element Vector{SubArray{Int64, 1, Vector{Int64}, Tuple{UnitRange{Int64}}, true}}:
#  [10097]
#  0-element view(::Vector{Int64}, 2:1) with eltype Int64
#  [15678]
#  [2251, 7826, 12474, 12739, 16017, 17213, 18486]
#  [6439, 14378, 15549, 17221]
#  [3723, 6369, 9087, 10163, 19687]
#  [8317, 13265, 17366]
#  [1441, 6337, 11951, 18094]
#  0-element view(::Vector{Int64}, 26:25) with eltype Int64
#  [11138, 14146]
#  [517]
#  [19220]
#  [11209]
#  ⋮
#  [5912, 15440]
#  [10006, 10087]
#  [6791]
#  [3299, 15782]
#  [1184, 9773]
#  [16212]
#  [2346, 8210, 9327, 9508, 19289]
#  [3438, 17515]
#  [3791, 10391]
#  [5111, 17399]
#  [16671]
#  [2106]

# %%
B[:, 4]
# Out:
# 20000-element SparseVector{Bool, Int64} with 7 stored entries:
#   [2251 ]  =  1
#   [7826 ]  =  1
#   [12474]  =  1
#   [12739]  =  1
#   [16017]  =  1
#   [17213]  =  1
#   [18486]  =  1

# %%
Random.seed!(12345678)

n = 20000
p = 0.1
@time A = Symmetric(sprand(Bool, n, n, p)) # test adjacency matrix
@time B = sparse(A)
@time C = nzptr.(Ref(B), axes(B, 2)) # adjacency list
# Out:
#   0.444366 seconds (8 allocations: 343.725 MiB, 1.56% gc time)
#   0.430075 seconds (13 allocations: 687.165 MiB, 5.74% gc time)
#   0.000273 seconds (6 allocations: 781.453 KiB)
# 20000-element Vector{SubArray{Int64, 1, Vector{Int64}, Tuple{UnitRange{Int64}}, true}}:
#  [5, 6, 8, 10, 37, 40, 50, 60, 70, 87  …  19902, 19907, 19908, 19911, 19925, 19926, 19930, 19947, 19958, 19981]
#  [2, 23, 24, 35, 47, 63, 66, 68, 90, 96  …  19898, 19904, 19911, 19929, 19933, 19936, 19955, 19963, 19977, 19988]
#  [6, 10, 14, 21, 38, 39, 53, 55, 56, 64  …  19946, 19951, 19952, 19953, 19960, 19967, 19972, 19985, 19997, 19999]
#  [8, 20, 23, 24, 25, 30, 41, 52, 59, 72  …  19904, 19915, 19920, 19959, 19960, 19971, 19975, 19985, 19991, 20000]
#  [1, 26, 47, 55, 63, 104, 106, 107, 115, 118  …  19938, 19939, 19950, 19951, 19953, 19956, 19961, 19969, 19972, 19973]
#  [1, 3, 8, 20, 26, 28, 46, 54, 59, 76  …  19883, 19890, 19905, 19908, 19921, 19949, 19952, 19963, 19977, 19980]
#  [30, 32, 37, 45, 62, 70, 74, 77, 99, 110  …  19955, 19956, 19962, 19965, 19967, 19971, 19978, 19980, 19984, 19997]
#  [1, 4, 6, 9, 28, 39, 68, 93, 115, 142  …  19876, 19895, 19918, 19922, 19948, 19956, 19963, 19977, 19987, 19993]
#  [8, 16, 20, 21, 29, 44, 47, 61, 101, 127  …  19873, 19876, 19896, 19906, 19908, 19946, 19958, 19965, 19967, 19988]
#  [1, 3, 15, 24, 27, 41, 54, 56, 74, 86  …  19928, 19929, 19933, 19934, 19939, 19941, 19947, 19954, 19958, 20000]
#  [11, 13, 19, 20, 33, 44, 49, 55, 59, 64  …  19902, 19929, 19932, 19944, 19957, 19960, 19969, 19970, 19973, 19978]
#  [15, 32, 41, 44, 50, 56, 57, 64, 76, 77  …  19925, 19926, 19949, 19957, 19967, 19968, 19972, 19985, 19987, 19996]
#  [11, 42, 45, 91, 106, 114, 119, 122, 130, 152  …  19939, 19943, 19945, 19946, 19951, 19953, 19962, 19964, 19982, 20000]
#  ⋮
#  [52, 54, 71, 84, 95, 96, 107, 121, 133, 134  …  19934, 19935, 19963, 19970, 19976, 19979, 19982, 19983, 19989, 19996]
#  [21, 58, 61, 64, 78, 81, 93, 98, 111, 117  …  19885, 19895, 19901, 19903, 19907, 19917, 19935, 19939, 19953, 19954]
#  [4, 19, 35, 37, 43, 44, 48, 52, 67, 71  …  19907, 19922, 19929, 19939, 19947, 19953, 19962, 19963, 19983, 19986]
#  [37, 39, 43, 45, 49, 52, 65, 70, 76, 83  …  19927, 19936, 19938, 19943, 19958, 19967, 19981, 19985, 19995, 19996]
#  [8, 23, 24, 26, 27, 30, 35, 56, 58, 90  …  19891, 19895, 19903, 19908, 19928, 19938, 19942, 19949, 19971, 19982]
#  [14, 23, 36, 38, 39, 44, 52, 58, 65, 71  …  19901, 19905, 19908, 19944, 19950, 19960, 19969, 19975, 19981, 19995]
#  [33, 38, 50, 51, 52, 58, 69, 92, 99, 117  …  19899, 19916, 19929, 19938, 19951, 19968, 19974, 19983, 19992, 19994]
#  [12, 28, 32, 38, 50, 52, 79, 103, 117, 118  …  19939, 19958, 19961, 19965, 19970, 19973, 19974, 19979, 19989, 19992]
#  [3, 7, 15, 21, 24, 27, 45, 46, 54, 57  …  19925, 19939, 19945, 19951, 19953, 19955, 19959, 19964, 19983, 19988]
#  [17, 22, 26, 28, 38, 39, 42, 45, 47, 49  …  19927, 19942, 19945, 19957, 19959, 19961, 19965, 19970, 19983, 19998]
#  [3, 30, 35, 51, 62, 71, 86, 95, 99, 101  …  19914, 19917, 19928, 19940, 19942, 19946, 19964, 19972, 19982, 19983]
#  [4, 10, 13, 22, 26, 27, 36, 37, 49, 60  …  19907, 19910, 19913, 19918, 19933, 19945, 19965, 19966, 19969, 19979]

# %%
B[:, 1]
# Out:
# 20000-element SparseVector{Bool, Int64} with 1970 stored entries:
#   [5    ]  =  1
#   [6    ]  =  1
#   [8    ]  =  1
#   [10   ]  =  1
#   [37   ]  =  1
#   [40   ]  =  1
#   [50   ]  =  1
#   [60   ]  =  1
#   [70   ]  =  1
#   [87   ]  =  1
#            ⋮
#   [19888]  =  1
#   [19902]  =  1
#   [19907]  =  1
#   [19908]  =  1
#   [19911]  =  1
#   [19925]  =  1
#   [19926]  =  1
#   [19930]  =  1
#   [19947]  =  1
#   [19958]  =  1
#   [19981]  =  1
