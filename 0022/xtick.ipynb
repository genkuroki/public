# %%
using Plots, Random
n = 20
# Out:
# 20

# %%
y = sort(rand(n); rev=true)
bar(y; xtick=1:20)

# %%
x = sort([randstring(2) for _ in 1:n])
y = sort(rand(n); rev=true)
bar(y; xtick=(1:n, x))

# %%
bar(y; group=rand(1:3, n), alpha=0.3)
