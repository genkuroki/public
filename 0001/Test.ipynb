# %%
using Plots
plot(sin)

# %%
pyplot(fmt=:svg)
plot(sin)

# %%
plotly(fmt=:auto)
plot(sin)
# Out:
# ┌ Info: For saving to png with the Plotly backend PlotlyBase has to be installed.
# └ @ Plots D:\.julia\packages\Plots\iYDwd\src\backends.jl:372
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#
#     </head>
#     <body>
#             <div id="57d23ce2-8d26-4b9e-b717-207797d1d2cc" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-1.57.1.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#         var PLOT = document.getElementById('57d23ce2-8d26-4b9e-b717-207797d1d2cc');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             -5.0,
#             -4.975585452450529,
#             -4.951170904901059,
#             -4.926756357351589,
# ...

# %% [markdown]
# https://nbviewer.jupyter.org/github/genkuroki/public/blob/main/0001/Test.ipynb
