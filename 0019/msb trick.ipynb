# %% [markdown]
# https://twitter.com/mkashi/status/1434847564256268291

# %%
ENV["LINES"] = 1000
# Out:
# 1000

# %%
function msb64(x)
    ε = eps(Float64)
    q = (1/ε + 1) * x
    m = q - (1 - ε/2) * q
    Int64(m)
end

@show eps(Float64) == 1/2^52

[(x = 2^k; (k, log2(msb64(x - 2)), log2(msb64(x - 1)), log2(msb64(x)))) for k in 1:54]
# Out:
# eps(Float64) == 1 / 2 ^ 52 = true
# 54-element Vector{Tuple{Int64, Float64, Float64, Float64}}:
#  (1, -Inf, 0.0, 1.0)
#  (2, 1.0, 1.0, 2.0)
#  (3, 2.0, 2.0, 3.0)
#  (4, 3.0, 3.0, 4.0)
#  (5, 4.0, 4.0, 5.0)
#  (6, 5.0, 5.0, 6.0)
#  (7, 6.0, 6.0, 7.0)
#  (8, 7.0, 7.0, 8.0)
#  (9, 8.0, 8.0, 9.0)
#  (10, 9.0, 9.0, 10.0)
#  (11, 10.0, 10.0, 11.0)
#  (12, 11.0, 11.0, 12.0)
#  (13, 12.0, 12.0, 13.0)
#  (14, 13.0, 13.0, 14.0)
#  (15, 14.0, 14.0, 15.0)
#  (16, 15.0, 15.0, 16.0)
#  (17, 16.0, 16.0, 17.0)
#  (18, 17.0, 17.0, 18.0)
#  (19, 18.0, 18.0, 19.0)
#  (20, 19.0, 19.0, 20.0)
#  (21, 20.0, 20.0, 21.0)
#  (22, 21.0, 21.0, 22.0)
#  (23, 22.0, 22.0, 23.0)
#  (24, 23.0, 23.0, 24.0)
#  (25, 24.0, 24.0, 25.0)
#  (26, 25.0, 25.0, 26.0)
#  (27, 26.0, 26.0, 27.0)
#  (28, 27.0, 27.0, 28.0)
#  (29, 28.0, 28.0, 29.0)
#  (30, 29.0, 29.0, 30.0)
#  (31, 30.0, 30.0, 31.0)
#  (32, 31.0, 31.0, 32.0)
#  (33, 32.0, 32.0, 33.0)
#  (34, 33.0, 33.0, 34.0)
#  (35, 34.0, 34.0, 35.0)
#  (36, 35.0, 35.0, 36.0)
#  (37, 36.0, 36.0, 37.0)
#  (38, 37.0, 37.0, 38.0)
#  (39, 38.0, 38.0, 39.0)
#  (40, 39.0, 39.0, 40.0)
#  (41, 40.0, 40.0, 41.0)
#  (42, 41.0, 41.0, 42.0)
#  (43, 42.0, 42.0, 43.0)
#  (44, 43.0, 43.0, 44.0)
#  (45, 44.0, 44.0, 45.0)
#  (46, 45.0, 45.0, 46.0)
#  (47, 46.0, 46.0, 47.0)
#  (48, 47.0, 47.0, 48.0)
#  (49, 48.0, 48.0, 49.0)
#  (50, 49.0, 49.0, 50.0)
#  (51, 50.0, 50.0, 51.0)
#  (52, 51.0, 51.0, 52.0)
#  (53, 52.0, 52.0, 53.0)
#  (54, 53.0, 54.0, 54.0)

# %%
using Quadmath

function msb128(x)
    ε = eps(Float128)
    q = (1/ε + 1) * x
    m = q - (1 - ε/2) * q
    Int128(m)
end

@show eps(Float128) == 1/Int128(2)^112

[(x = Int128(2)^k; (k, log2(msb128(x - 2)), log2(msb128(x - 1)), log2(msb128(x)))) for k in 1:114]
# Out:
# eps(Float128) == 1 / Int128(2) ^ 112 = true
# 114-element Vector{Tuple{Int64, Float64, Float64, Float64}}:
#  (1, -Inf, 0.0, 1.0)
#  (2, 1.0, 1.0, 2.0)
#  (3, 2.0, 2.0, 3.0)
#  (4, 3.0, 3.0, 4.0)
#  (5, 4.0, 4.0, 5.0)
#  (6, 5.0, 5.0, 6.0)
#  (7, 6.0, 6.0, 7.0)
#  (8, 7.0, 7.0, 8.0)
#  (9, 8.0, 8.0, 9.0)
#  (10, 9.0, 9.0, 10.0)
#  (11, 10.0, 10.0, 11.0)
#  (12, 11.0, 11.0, 12.0)
#  (13, 12.0, 12.0, 13.0)
#  (14, 13.0, 13.0, 14.0)
#  (15, 14.0, 14.0, 15.0)
#  (16, 15.0, 15.0, 16.0)
#  (17, 16.0, 16.0, 17.0)
#  (18, 17.0, 17.0, 18.0)
#  (19, 18.0, 18.0, 19.0)
#  (20, 19.0, 19.0, 20.0)
#  (21, 20.0, 20.0, 21.0)
#  (22, 21.0, 21.0, 22.0)
#  (23, 22.0, 22.0, 23.0)
#  (24, 23.0, 23.0, 24.0)
#  (25, 24.0, 24.0, 25.0)
#  (26, 25.0, 25.0, 26.0)
#  (27, 26.0, 26.0, 27.0)
#  (28, 27.0, 27.0, 28.0)
#  (29, 28.0, 28.0, 29.0)
#  (30, 29.0, 29.0, 30.0)
#  (31, 30.0, 30.0, 31.0)
#  (32, 31.0, 31.0, 32.0)
#  (33, 32.0, 32.0, 33.0)
#  (34, 33.0, 33.0, 34.0)
#  (35, 34.0, 34.0, 35.0)
#  (36, 35.0, 35.0, 36.0)
#  (37, 36.0, 36.0, 37.0)
#  (38, 37.0, 37.0, 38.0)
#  (39, 38.0, 38.0, 39.0)
#  (40, 39.0, 39.0, 40.0)
#  (41, 40.0, 40.0, 41.0)
#  (42, 41.0, 41.0, 42.0)
#  (43, 42.0, 42.0, 43.0)
#  (44, 43.0, 43.0, 44.0)
#  (45, 44.0, 44.0, 45.0)
#  (46, 45.0, 45.0, 46.0)
#  (47, 46.0, 46.0, 47.0)
#  (48, 47.0, 47.0, 48.0)
#  (49, 48.0, 48.0, 49.0)
#  (50, 49.0, 49.0, 50.0)
#  (51, 50.0, 50.0, 51.0)
#  (52, 51.0, 51.0, 52.0)
#  (53, 52.0, 52.0, 53.0)
#  (54, 53.0, 53.0, 54.0)
#  (55, 54.0, 54.0, 55.0)
#  (56, 55.0, 55.0, 56.0)
#  (57, 56.0, 56.0, 57.0)
#  (58, 57.0, 57.0, 58.0)
#  (59, 58.0, 58.0, 59.0)
#  (60, 59.0, 59.0, 60.0)
#  (61, 60.0, 60.0, 61.0)
#  (62, 61.0, 61.0, 62.0)
#  (63, 62.0, 62.0, 63.0)
#  (64, 63.0, 63.0, 64.0)
#  (65, 64.0, 64.0, 65.0)
#  (66, 65.0, 65.0, 66.0)
#  (67, 66.0, 66.0, 67.0)
#  (68, 67.0, 67.0, 68.0)
#  (69, 68.0, 68.0, 69.0)
#  (70, 69.0, 69.0, 70.0)
#  (71, 70.0, 70.0, 71.0)
#  (72, 71.0, 71.0, 72.0)
#  (73, 72.0, 72.0, 73.0)
#  (74, 73.0, 73.0, 74.0)
#  (75, 74.0, 74.0, 75.0)
#  (76, 75.0, 75.0, 76.0)
#  (77, 76.0, 76.0, 77.0)
#  (78, 77.0, 77.0, 78.0)
#  (79, 78.0, 78.0, 79.0)
#  (80, 79.0, 79.0, 80.0)
#  (81, 80.0, 80.0, 81.0)
#  (82, 81.0, 81.0, 82.0)
#  (83, 82.0, 82.0, 83.0)
#  (84, 83.0, 83.0, 84.0)
#  (85, 84.0, 84.0, 85.0)
#  (86, 85.0, 85.0, 86.0)
#  (87, 86.0, 86.0, 87.0)
#  (88, 87.0, 87.0, 88.0)
#  (89, 88.0, 88.0, 89.0)
#  (90, 89.0, 89.0, 90.0)
#  (91, 90.0, 90.0, 91.0)
#  (92, 91.0, 91.0, 92.0)
#  (93, 92.0, 92.0, 93.0)
#  (94, 93.0, 93.0, 94.0)
#  (95, 94.0, 94.0, 95.0)
#  (96, 95.0, 95.0, 96.0)
#  (97, 96.0, 96.0, 97.0)
#  (98, 97.0, 97.0, 98.0)
#  (99, 98.0, 98.0, 99.0)
#  (100, 99.0, 99.0, 100.0)
#  (101, 100.0, 100.0, 101.0)
#  (102, 101.0, 101.0, 102.0)
#  (103, 102.0, 102.0, 103.0)
#  (104, 103.0, 103.0, 104.0)
#  (105, 104.0, 104.0, 105.0)
#  (106, 105.0, 105.0, 106.0)
#  (107, 106.0, 106.0, 107.0)
#  (108, 107.0, 107.0, 108.0)
#  (109, 108.0, 108.0, 109.0)
#  (110, 109.0, 109.0, 110.0)
#  (111, 110.0, 110.0, 111.0)
#  (112, 111.0, 111.0, 112.0)
#  (113, 112.0, 112.0, 113.0)
#  (114, 113.0, 114.0, 114.0)

# %%
function msb(x)
    ε = eps(float(typeof(x)))
    q = (1/ε + 1) * x
    m = q - (1 - ε/2) * q
    oftype(x, m)
end
# Out:
# msb (generic function with 1 method)

# %%
@show precision(Float64)
@show eps(Float64) == 1/2^(precision(Float64)-1)
[(x = 2^k; (k, log2(msb(x - 2)), log2(msb(x - 1)), log2(msb(x)))) for k in 1:precision(Float64)+1]
# Out:
# precision(Float64) = 53
# eps(Float64) == 1 / 2 ^ (precision(Float64) - 1) = true
# 54-element Vector{Tuple{Int64, Float64, Float64, Float64}}:
#  (1, -Inf, 0.0, 1.0)
#  (2, 1.0, 1.0, 2.0)
#  (3, 2.0, 2.0, 3.0)
#  (4, 3.0, 3.0, 4.0)
#  (5, 4.0, 4.0, 5.0)
#  (6, 5.0, 5.0, 6.0)
#  (7, 6.0, 6.0, 7.0)
#  (8, 7.0, 7.0, 8.0)
#  (9, 8.0, 8.0, 9.0)
#  (10, 9.0, 9.0, 10.0)
#  (11, 10.0, 10.0, 11.0)
#  (12, 11.0, 11.0, 12.0)
#  (13, 12.0, 12.0, 13.0)
#  (14, 13.0, 13.0, 14.0)
#  (15, 14.0, 14.0, 15.0)
#  (16, 15.0, 15.0, 16.0)
#  (17, 16.0, 16.0, 17.0)
#  (18, 17.0, 17.0, 18.0)
#  (19, 18.0, 18.0, 19.0)
#  (20, 19.0, 19.0, 20.0)
#  (21, 20.0, 20.0, 21.0)
#  (22, 21.0, 21.0, 22.0)
#  (23, 22.0, 22.0, 23.0)
#  (24, 23.0, 23.0, 24.0)
#  (25, 24.0, 24.0, 25.0)
#  (26, 25.0, 25.0, 26.0)
#  (27, 26.0, 26.0, 27.0)
#  (28, 27.0, 27.0, 28.0)
#  (29, 28.0, 28.0, 29.0)
#  (30, 29.0, 29.0, 30.0)
#  (31, 30.0, 30.0, 31.0)
#  (32, 31.0, 31.0, 32.0)
#  (33, 32.0, 32.0, 33.0)
#  (34, 33.0, 33.0, 34.0)
#  (35, 34.0, 34.0, 35.0)
#  (36, 35.0, 35.0, 36.0)
#  (37, 36.0, 36.0, 37.0)
#  (38, 37.0, 37.0, 38.0)
#  (39, 38.0, 38.0, 39.0)
#  (40, 39.0, 39.0, 40.0)
#  (41, 40.0, 40.0, 41.0)
#  (42, 41.0, 41.0, 42.0)
#  (43, 42.0, 42.0, 43.0)
#  (44, 43.0, 43.0, 44.0)
#  (45, 44.0, 44.0, 45.0)
#  (46, 45.0, 45.0, 46.0)
#  (47, 46.0, 46.0, 47.0)
#  (48, 47.0, 47.0, 48.0)
#  (49, 48.0, 48.0, 49.0)
#  (50, 49.0, 49.0, 50.0)
#  (51, 50.0, 50.0, 51.0)
#  (52, 51.0, 51.0, 52.0)
#  (53, 52.0, 52.0, 53.0)
#  (54, 53.0, 54.0, 54.0)

# %%
@show precision(BigFloat)
@show eps(BigFloat) == 1/big(2)^(precision(BigFloat)-1)
[(x = big(2)^k; (k, log2(msb(x - 2)), log2(msb(x - 1)), log2(msb(x)))) for k in 1:precision(BigFloat)+1]
# Out:
# precision(BigFloat) = 256
# eps(BigFloat) == 1 / big(2) ^ (precision(BigFloat) - 1) = true
# 257-element Vector{Tuple{Int64, BigFloat, BigFloat, BigFloat}}:
#  (1, -Inf, 0.0, 1.0)
#  (2, 1.0, 1.0, 2.0)
#  (3, 2.0, 2.0, 3.0)
#  (4, 3.0, 3.0, 4.0)
#  (5, 4.0, 4.0, 5.0)
#  (6, 5.0, 5.0, 6.0)
#  (7, 6.0, 6.0, 7.0)
#  (8, 7.0, 7.0, 8.0)
#  (9, 8.0, 8.0, 9.0)
#  (10, 9.0, 9.0, 10.0)
#  (11, 10.0, 10.0, 11.0)
#  (12, 11.0, 11.0, 12.0)
#  (13, 12.0, 12.0, 13.0)
#  (14, 13.0, 13.0, 14.0)
#  (15, 14.0, 14.0, 15.0)
#  (16, 15.0, 15.0, 16.0)
#  (17, 16.0, 16.0, 17.0)
#  (18, 17.0, 17.0, 18.0)
#  (19, 18.0, 18.0, 19.0)
#  (20, 19.0, 19.0, 20.0)
#  (21, 20.0, 20.0, 21.0)
#  (22, 21.0, 21.0, 22.0)
#  (23, 22.0, 22.0, 23.0)
#  (24, 23.0, 23.0, 24.0)
#  (25, 24.0, 24.0, 25.0)
#  (26, 25.0, 25.0, 26.0)
#  (27, 26.0, 26.0, 27.0)
#  (28, 27.0, 27.0, 28.0)
#  (29, 28.0, 28.0, 29.0)
#  (30, 29.0, 29.0, 30.0)
#  (31, 30.0, 30.0, 31.0)
#  (32, 31.0, 31.0, 32.0)
#  (33, 32.0, 32.0, 33.0)
#  (34, 33.0, 33.0, 34.0)
#  (35, 34.0, 34.0, 35.0)
#  (36, 35.0, 35.0, 36.0)
#  (37, 36.0, 36.0, 37.0)
#  (190, 189.0, 189.0, 190.0)
#  (191, 190.0, 190.0, 191.0)
#  (192, 191.0, 191.0, 192.0)
#  (193, 192.0, 192.0, 193.0)
#  (194, 193.0, 193.0, 194.0)
#  (195, 194.0, 194.0, 195.0)
#  (196, 195.0, 195.0, 196.0)
#  (197, 196.0, 196.0, 197.0)
#  (198, 197.0, 197.0, 198.0)
#  (199, 198.0, 198.0, 199.0)
#  (200, 199.0, 199.0, 200.0)
#  (201, 200.0, 200.0, 201.0)
#  (202, 201.0, 201.0, 202.0)
#  (203, 202.0, 202.0, 203.0)
#  (204, 203.0, 203.0, 204.0)
#  (205, 204.0, 204.0, 205.0)
#  (206, 205.0, 205.0, 206.0)
#  (207, 206.0, 206.0, 207.0)
#  (208, 207.0, 207.0, 208.0)
#  (209, 208.0, 208.0, 209.0)
#  (210, 209.0, 209.0, 210.0)
#  (211, 210.0, 210.0, 211.0)
#  (212, 211.0, 211.0, 212.0)
#  (213, 212.0, 212.0, 213.0)
#  (214, 213.0, 213.0, 214.0)
#  (215, 214.0, 214.0, 215.0)
#  (216, 215.0, 215.0, 216.0)
#  (217, 216.0, 216.0, 217.0)
#  (218, 217.0, 217.0, 218.0)
#  (219, 218.0, 218.0, 219.0)
#  (220, 219.0, 219.0, 220.0)
#  (221, 220.0, 220.0, 221.0)
#  (222, 221.0, 221.0, 222.0)
#  (223, 222.0, 222.0, 223.0)
#  (224, 223.0, 223.0, 224.0)
#  (225, 224.0, 224.0, 225.0)
#  (226, 225.0, 225.0, 226.0)
#  (227, 226.0, 226.0, 227.0)
#  (228, 227.0, 227.0, 228.0)
#  (229, 228.0, 228.0, 229.0)
#  (230, 229.0, 229.0, 230.0)
#  (231, 230.0, 230.0, 231.0)
#  (232, 231.0, 231.0, 232.0)
#  (233, 232.0, 232.0, 233.0)
#  (234, 233.0, 233.0, 234.0)
#  (235, 234.0, 234.0, 235.0)
#  (236, 235.0, 235.0, 236.0)
#  (237, 236.0, 236.0, 237.0)
#  (238, 237.0, 237.0, 238.0)
#  (239, 238.0, 238.0, 239.0)
#  (240, 239.0, 239.0, 240.0)
#  (241, 240.0, 240.0, 241.0)
#  (242, 241.0, 241.0, 242.0)
#  (243, 242.0, 242.0, 243.0)
#  (244, 243.0, 243.0, 244.0)
#  (245, 244.0, 244.0, 245.0)
#  (246, 245.0, 245.0, 246.0)
#  (247, 246.0, 246.0, 247.0)
#  (248, 247.0, 247.0, 248.0)
#  (249, 248.0, 248.0, 249.0)
#  (250, 249.0, 249.0, 250.0)
#  (251, 250.0, 250.0, 251.0)
#  (252, 251.0, 251.0, 252.0)
#  (253, 252.0, 252.0, 253.0)
#  (254, 253.0, 253.0, 254.0)
#  (255, 254.0, 254.0, 255.0)
#  (256, 255.0, 255.0, 256.0)
#  (257, 256.0, 257.0, 257.0)

# %%
@code_typed msb(12345)
# Out:
# CodeInfo(
# 1 ── %1  = Base.sitofp(Float64, x)::Float64
# │    %2  = Base.mul_float(4.503599627370497e15, %1)::Float64
# │    %3  = Base.mul_float(0.9999999999999999, %2)::Float64
# │    %4  = Base.sub_float(%2, %3)::Float64
# │    %5  = Base.le_float(-9.223372036854776e18, %4)::Bool
# └───       goto #3 if not %5
# 2 ── %7  = Base.lt_float(%4, 9.223372036854776e18)::Bool
# └───       goto #4
# 3 ──       nothing::Nothing
# 4 ┄─ %10 = φ (#2 => %7, #3 => false)::Bool
# └───       goto #7 if not %10
# 5 ── %12 = Base.trunc_llvm(%4)::Float64
# │    %13 = Base.eq_float(%12, %4)::Bool
# └───       goto #7 if not %13
# 6 ── %15 = Base.fptosi(Int64, %4)::Int64
# └───       goto #8
# 7 ┄─ %17 = Base.InexactError(:Int64, Int64, %4)::Any
# │          Base.throw(%17)::Union{}
# └───       unreachable
# 8 ──       goto #9
# 9 ──       goto #10
# 10 ─       return %15
# ) => Int64

# %%
@code_native debuginfo=:none msb(12345)
# Out:
# 	.text
# 	pushq	%rbp
# 	movq	%rsp, %rbp
# 	pushq	%rsi
# 	subq	$120, %rsp
# 	vmovaps	%xmm6, -32(%rbp)
# 	movq	%rcx, %rsi
# 	vxorpd	%xmm0, %xmm0, %xmm0
# 	vmovapd	%xmm0, -64(%rbp)
# 	movq	$0, -48(%rbp)
# 	movl	$jl_get_ptls_states, %eax
# 	callq	*%rax
# 	movq	$4, -64(%rbp)
# 	movq	(%rax), %rcx
# 	movq	%rcx, -56(%rbp)
# 	leaq	-64(%rbp), %rcx
# 	movq	%rcx, (%rax)
# 	vcvtsi2sd	%rsi, %xmm1, %xmm0
# 	movabsq	$.rodata.cst8, %rcx
# 	vmulsd	(%rcx), %xmm0, %xmm0
# 	movabsq	$1571826712, %rcx               # imm = 0x5DB02C18
# 	vmulsd	(%rcx), %xmm0, %xmm1
# 	vaddsd	%xmm1, %xmm0, %xmm6
# 	movabsq	$1571826720, %rcx               # imm = 0x5DB02C20
# 	vucomisd	(%rcx), %xmm6
# 	jb	L177
# 	movabsq	$1571826728, %rcx               # imm = 0x5DB02C28
# 	vmovsd	(%rcx), %xmm0                   # xmm0 = mem[0],zero
# 	vucomisd	%xmm6, %xmm0
# 	jbe	L177
# 	vroundsd	$11, %xmm6, %xmm6, %xmm0
# 	vucomisd	%xmm6, %xmm0
# 	jne	L177
# 	jp	L177
# 	vcvttsd2si	%xmm6, %rcx
# 	movq	-56(%rbp), %rdx
# 	movq	%rdx, (%rax)
# 	movq	%rcx, %rax
# 	vmovaps	-32(%rbp), %xmm6
# 	addq	$120, %rsp
# 	popq	%rsi
# 	popq	%rbp
# 	retq
# L177:
# 	movabsq	$jl_gc_pool_alloc, %rsi
# 	movq	%rax, %rcx
# 	movl	$1400, %edx                     # imm = 0x578
# 	movl	$16, %r8d
# 	callq	*%rsi
# 	movq	$273101312, -8(%rax)            # imm = 0x10473200
# 	vmovsd	%xmm6, (%rax)
# 	movq	%rax, -48(%rbp)
# 	movq	$242500104, -88(%rbp)           # imm = 0xE744208
# 	movq	$271395360, -80(%rbp)           # imm = 0x102D2A20
# 	movq	%rax, -72(%rbp)
# 	movabsq	$jl_apply_generic, %rax
# 	leaq	-88(%rbp), %rdx
# 	movl	$323707840, %ecx                # imm = 0x134B63C0
# 	movl	$3, %r8d
# 	callq	*%rax
# 	movabsq	$jl_throw, %rdx
# 	movq	%rax, %rcx
# 	callq	*%rdx
# 	nopl	(%rax)
