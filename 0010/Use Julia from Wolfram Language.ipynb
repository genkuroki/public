# %%
fib[n_] := If[n<=1, n, fib[n - 2] + fib[n - 1]];
AbsoluteTiming[fib[30]]
# Out:
# {2.75915, 832040}

# %%
FindExternalEvaluators[]
# Out:
# Dataset[<|R -> <|c1af1de7-3113-755c-c808-40128393ba88 ->
#
# >       <|System -> R, Version -> ,
#
# >        Target :>
#
# >         C:\Program Files\Wolfram Research\Wolfram\
#
# >          Engine\12.3\SystemFiles\Links\RLink\Java\REngine.jar,
#
# >        Executable :>
#
# >         C:\Program Files\Wolfram Research\Wolfram\
#
# >          Engine\12.3\SystemFiles\Links\RLink\Java\REngine.jar,
#
# >        Registered -> Automatic|>|>,
#
# >    Java -> <|ec88b02a-222f-c5f8-1708-19a7c393ff6a ->
#
# >       <|System -> Java, Version -> 1.0,
#
# >        Target :>
#
# >         C:\Program Files\Wolfram Research\Wolfram\
#
# >          Engine\12.3\SystemFiles\Links\JLink\JLink.jar,
#
# >        Executable :>
#
# >         C:\Program Files\Wolfram Research\Wolfram\
#
# >          Engine\12.3\SystemFiles\Links\JLink\JLink.jar, Registered -> Automatic|>|>,
#
# >    Shell -> <|3b112243-5f37-782e-510f-74875c638691 ->
#
# >       <|System -> Shell, Version -> Missing[NotAvailable],
#
# >        Target :> C:\Windows\system32\cmd.exe,
#
# >        Executable :> C:\Windows\system32\cmd.exe, Registered -> Automatic|>,
#
# >      55d5928c-a44a-eb7d-c535-626e08006c8a ->
#
# >       <|System -> Shell, Version -> Missing[NotAvailable],
#
# >        Target :> C:\Windows\system32\WindowsPowerShell\v1.0\powershell.exe,
#
# >        Executable :> C:\Windows\system32\WindowsPowerShell\v1.0\powershell.exe,
#
# >        Registered -> Automatic|>|>,
#
# >    Jupyter -> <|9d15b026-01e9-0985-ea87-f148470cc17e ->
#
# >       <|System -> Jupyter, Version -> ir,
#
# >        Target :> C:\Users\genkuroki\AppData\Roaming\jupyter\kernels\ir\kernel.json,
#
# >        Executable :>
#
# >         C:\Users\genkuroki\AppData\Roaming\jupyter\kernels\ir\kernel.json,
#
# >        Registered -> Automatic|>,
#
# >      2658e17f-ec14-70ec-815e-50f8a5f37391 ->
#
# >       <|System -> Jupyter, Version -> julia-1.6,
#
# >        Target :>
#
# >         C:\Users\genkuroki\AppData\Roaming\jupyter\kernels\julia-1.6\kernel.json,
#
# >        Executable :>
#
# >         C:\Users\genkuroki\AppData\Roaming\jupyter\kernels\julia-1.6\kernel.json,
#
# >        Registered -> Automatic|>,
#
# >      12e43592-dbe6-eaa4-9b28-cb4d44b456e5 ->
#
# >       <|System -> Jupyter, Version -> julia-1.7,
#
# >        Target :>
#
# >         C:\Users\genkuroki\AppData\Roaming\jupyter\kernels\julia-1.7\kernel.json,
#
# >        Executable :>
#
# >         C:\Users\genkuroki\AppData\Roaming\jupyter\kernels\julia-1.7\kernel.json,
#
# >        Registered -> Automatic|>,
#
# >      925242b4-35c5-fa15-14c4-815895ffb998 ->
#
# >       <|System -> Jupyter, Version -> julia-1.8,
#
# >        Target :>
#
# >         C:\Users\genkuroki\AppData\Roaming\jupyter\kernels\julia-1.8\kernel.json,
#
# >        Executable :>
#
# >         C:\Users\genkuroki\AppData\Roaming\jupyter\kernels\julia-1.8\kernel.json,
#
# >        Registered -> Automatic|>,
#
# >      48d2f8b9-7db4-2ab5-8ce2-2133e814f41a ->
#
# >       <|System -> Jupyter, Version -> wolframlanguage12.3,
#
# >        Target :>
#
# >         C:\Users\genkuroki\AppData\Roaming\jupyter\kernels\wolframlanguage12.3\kernel.\
#
# >          json, Executable :>
#
# >         C:\Users\genkuroki\AppData\Roaming\jupyter\kernels\wolframlanguage12.3\kernel.\
#
# >          json, Registered -> Automatic|>,
#
# >      d832c488-d99e-1bfd-6c5b-2b125c41a735 ->
#
# >       <|System -> Jupyter, Version -> python3,
#
# >        Target :> D:\.julia\conda\3\share\jupyter\kernels\python3\kernel.json,
#
# >        Executable :> D:\.julia\conda\3\share\jupyter\kernels\python3\kernel.json,
#
# >        Registered -> Automatic|>|>|>,
#
# >   TypeSystem`Assoc[TypeSystem`Atom[String],
#
# >    TypeSystem`Assoc[TypeSystem`Atom[String],
#
# >     TypeSystem`Struct[{System, Version, Target, Executable, Registered},
#
# >      {TypeSystem`AnyType, TypeSystem`Atom[String], TypeSystem`Atom[String],
#
# >       TypeSystem`Atom[String], TypeSystem`AnyType}], TypeSystem`AnyLength], 4],
#
# >   <|HiddenItems -> {Executable}|>]

# %%
Environment["PATH"]
# Out:
# C:\Program Files\Wolfram Research\Wolfram\
#
# >   Engine\12.3\SystemFiles\Libraries\Windows-x86-64;D:\bin;D:\Julia-1.8.0-DEV\bin;D:\ms\
#
# >   ys64\mingw64\bin;D:\msys64\usr\bin;D:\texlive\2021\bin\win32;C:\Program Files\NVIDIA\
#
# >   GPU Computing Toolkit\CUDA\v11.3\bin;C:\Program Files\NVIDIA GPU Computing\
#
# >   Toolkit\CUDA\v11.3\libnvvp;C:\Program Files\Git\cmd;C:\Program\
#
# >   Files\R\R-4.1.0\bin;C:\Program Files\Wolfram Research\WolframScript\;C:\Program\
#
# >   Files\nteract\resources\bin\win;C:\Program Files (x86)\ZeroTier\One\;C:\Program\
#
# >   Files (x86)\Common\
#
# >   Files\Oracle\Java\javapath;C:\Windows\system32;C:\Windows;C:\Windows\System32\Wbem;C\
#
# >   :\Windows\System32\WindowsPowerShell\v1.0\;C:\Windows\System32\OpenSSH\;C:\Program\
#
# >   Files (x86)\NVIDIA Corporation\PhysX\Common;C:\Program Files\NVIDIA\
#
# >   Corporation\NVIDIA NvDLISR;C:\Program Files\Microsoft SQL\
#
# >   Server\130\Tools\Binn\;C:\Program Files\NVIDIA Corporation\Nsight Compute\
#
# >   2021.1.1\;C:\Program Files\Microsoft VS Code\bin;C:\Program Files\Microsoft VS Code\
#
# >   Insiders\bin;D:\.julia\conda\3;D:\.julia\conda\3\Scripts;D:\.julia\conda\3\Library\b\
#
# >   in;D:\.julia\conda\3\Lib\site-packages\zmq;C:\Users\genkuroki\AppData\Local\Microsof\
#
# >   t\WindowsApps;C:\Users\genkuroki\AppData\Local\GitHubDesktop\bin

# %%
juliaSession = StartExternalSession["Julia"]; (* Start Julia session *)

fibJulia = ExternalEvaluate[juliaSession,
    "fib(n) = n<=1 ? n : fib(n-2) + fib(n-1)"
];
(* defined Julia function callable from Mathematica *)

fibJulia[5]; (* JIT warmup for Julia *)

AbsoluteTiming[fibJulia[30]] (* Actual calculation *)
# Out:
# No valid installations for system `1` were found with the options specified.: No valid installations for system Julia were found with the options specified.
# `1` is not a known system in the ExternalEvaluate Framework.: $Failed is not a known system in the ExternalEvaluate Framework.
#       -7
# {6. 10  , ExternalEvaluate[$Failed, fib(n) = n<=1 ? n : fib(n-2) + fib(n-1)][30]}

# %%
juliaSession = StartExternalSession["Julia"]; (* Start Julia session *)
# Out:
# No valid installations for system `1` were found with the options specified.: No valid installations for system Julia were found with the options specified.

# %%
$Version
# Out:
# 12.3.0 for Microsoft Windows (64-bit) (May 10, 2021)
