# %% [markdown]
# * https://twitter.com/kdwkshh/status/1406620780457119745
# * https://discourse.julialang.org/t/ann-jettest-jl-advanced-testing-toolset-for-julia/63229
# * https://github.com/aviatesk/JETTest.jl

# %%
VERSION
# Out:
# v"1.8.0-DEV.57"

# %%
using JETTest
using Test

module O

struct Foo
    a::Vector
end

function Base.sum(foo::Foo)
    a = foo.a
    s = zero(eltype(a))
    for x in a
        s += x
    end
    s
end

end

foo = O.Foo(randn(10^3))
@show sum(foo)

println("\n", "="^80, "\n")

@report_dispatch sum(foo)

println("\n", "="^80, "\n")

@code_warntype sum(foo)

println("\n", "="^80, "\n")

@testset "check type-stabilities" begin
    @test_nodispatch sum(foo)
end
# Out:
# sum(foo) = -14.0663200027919
#
# ================================================================================
#
# ═════ 5 possible errors found ═════
# ┌ @ In[2]:12 Main.O.eltype(%1)
# │ runtime dispatch detected: Main.O.eltype(%1::Vector)
# └────────────
# ┌ @ In[2]:12 Main.O.zero(%2)
# │ runtime dispatch detected: Main.O.zero(%2::Any)
# └────────────
# ┌ @ array.jl:809 Base.getindex(%1, 1)
# │ runtime dispatch detected: Base.getindex(%1::Vector, 1)
# └────────────────
# ┌ @ In[2]:14 Main.O.+(%25, %23)
# │ runtime dispatch detected: Main.O.+(%25::Any, %23::Any)
# └────────────
# ┌ @ array.jl:809 Base.getindex(%1, %24)
# │ runtime dispatch detected: Base.getindex(%1::Vector, %24::Int64)
# └────────────────
#
# ================================================================================
#
# MethodInstance for sum(::Main.O.Foo)
#   from sum(foo::Main.O.Foo) in Main.O at In[2]:10
# Arguments
#   #self#::Core.Const(sum)
#   foo::Main.O.Foo
# Locals
#   @_3::Union{Nothing, Tuple{Any, Int64}}
#   s::Any
#   a::Vector
#   x::Any
# Body::Any
# 1 ─       (a = Base.getproperty(foo, :a))
# │   %2  = Main.O.eltype(a)::Any
# │         (s = Main.O.zero(%2))
# │   %4  = a::Vector
# │         (@_3 = Base.iterate(%4))
# │   %6  = (@_3 === nothing)::Bool
# │   %7  = Base.not_int(%6)::Bool
# └──       goto #4 if not %7
# 2 ┄ %9  = @_3::Tuple{Any, Int64}
# │         (x = Core.getfield(%9, 1))
# │   %11 = Core.getfield(%9, 2)::Int64
# │         (s = s + x)
# │         (@_3 = Base.iterate(%4, %11))
# │   %14 = (@_3 === nothing)::Bool
# │   %15 = Base.not_int(%14)::Bool
# └──       goto #4 if not %15
# 3 ─       goto #2
# 4 ┄       return s
#
#
# ================================================================================
#
# check type-stabilities: Dispatch Test Failed at In[2]:35
#   Expression: #= In[2]:35 =# JETTest.@test_nodispatch sum(foo)
#   ═════ 5 possible errors found ═════
#   ┌ @ In[2]:12 Main.O.eltype(%1)
#   │ runtime dispatch detected: Main.O.eltype(%1::Vector)
#   └────────────
#   ┌ @ In[2]:12 Main.O.zero(%2)
#   │ runtime dispatch detected: Main.O.zero(%2::Any)
#   └────────────
#   ┌ @ array.jl:809 Base.getindex(%1, 1)
#   │ runtime dispatch detected: Base.getindex(%1::Vector, 1)
#   └────────────────
#   ┌ @ In[2]:14 Main.O.+(%25, %23)
#   │ runtime dispatch detected: Main.O.+(%25::Any, %23::Any)
#   └────────────
#   ┌ @ array.jl:809 Base.getindex(%1, %24)
#   │ runtime dispatch detected: Base.getindex(%1::Vector, %24::Int64)
#   └────────────────
#
# Test Summary:          | Fail  Total
# check type-stabilities |    1      1
# Some tests did not pass: 0 passed, 1 failed, 0 errored, 0 broken.
#
# Stacktrace:
#  [1] finish(ts::Test.DefaultTestSet)
#    @ Test C:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.8\Test\src\Test.jl:1044
#  [2] macro expansion
#    @ C:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.8\Test\src\Test.jl:1292 [inlined]
#  [3] top-level scope
#    @ .\In[2]:35
#  [4] eval
#    @ .\boot.jl:373 [inlined]
#  [5] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1196

# %%
using JETTest
using Test

module O

struct Foo
    a::Vector{Real}
end

function Base.sum(foo::Foo)
    a = foo.a
    s = zero(eltype(a))
    for x in a
        s += x
    end
    s
end

end

foo = O.Foo(randn(10^3))
@show sum(foo)

println("\n", "="^80, "\n")

@report_dispatch sum(foo)

println("\n", "="^80, "\n")

@code_warntype sum(foo)

println("\n", "="^80, "\n")

@testset "check type-stabilities" begin
    @test_nodispatch sum(foo)
end
# Out:
# sum(foo) = 10.69172613125043
#
# ================================================================================
#
# ═════ 1 possible error found ═════
# ┌ @ In[3]:14 Main.O.+(%23, %21)
# │ runtime dispatch detected: Main.O.+(%23::Any, %21::Real)
# └────────────
#
# ================================================================================
#
# MethodInstance for sum(::Main.O.Foo)
#   from sum(foo::Main.O.Foo) in Main.O at In[3]:10
# Arguments
#   #self#::Core.Const(sum)
#   foo::Main.O.Foo
# Locals
#   @_3::Union{Nothing, Tuple{Real, Int64}}
#   s::Any
#   a::Vector{Real}
#   x::Real
# Body::Any
# 1 ─       (a = Base.getproperty(foo, :a))
# │   %2  = Main.O.eltype(a)::Core.Const(Real)
# │         (s = Main.O.zero(%2))
# │   %4  = a::Vector{Real}
# │         (@_3 = Base.iterate(%4))
# │   %6  = (@_3 === nothing)::Bool
# │   %7  = Base.not_int(%6)::Bool
# └──       goto #4 if not %7
# 2 ┄ %9  = @_3::Tuple{Real, Int64}
# │         (x = Core.getfield(%9, 1))
# │   %11 = Core.getfield(%9, 2)::Int64
# │         (s = s + x)
# │         (@_3 = Base.iterate(%4, %11))
# │   %14 = (@_3 === nothing)::Bool
# │   %15 = Base.not_int(%14)::Bool
# └──       goto #4 if not %15
# 3 ─       goto #2
# 4 ┄       return s
#
#
# ================================================================================
#
# check type-stabilities: Dispatch Test Failed at In[3]:35
#   Expression: #= In[3]:35 =# JETTest.@test_nodispatch sum(foo)
#   ═════ 1 possible error found ═════
#   ┌ @ In[3]:14 Main.O.+(%23, %21)
#   │ runtime dispatch detected: Main.O.+(%23::Any, %21::Real)
#   └────────────
#
# Test Summary:          | Fail  Total
# check type-stabilities |    1      1
# WARNING: replacing module O.
# Some tests did not pass: 0 passed, 1 failed, 0 errored, 0 broken.
#
# Stacktrace:
#  [1] finish(ts::Test.DefaultTestSet)
#    @ Test C:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.8\Test\src\Test.jl:1044
#  [2] macro expansion
#    @ C:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.8\Test\src\Test.jl:1292 [inlined]
#  [3] top-level scope
#    @ .\In[3]:35
#  [4] eval
#    @ .\boot.jl:373 [inlined]
#  [5] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1196

# %%
using JETTest
using Test

module O

struct Foo
    a::Array{Float64}
end

function Base.sum(foo::Foo)
    a = foo.a
    s = zero(eltype(a))
    for x in a
        s += x
    end
    s
end

end

foo = O.Foo(randn(10^3))
@show sum(foo)

println("\n", "="^80, "\n")

@report_dispatch sum(foo)

println("\n", "="^80, "\n")

@code_warntype sum(foo)

println("\n", "="^80, "\n")

@testset "check type-stabilities" begin
    @test_nodispatch sum(foo)
end
# Out:
# sum(foo) = -15.535427974685737
#
# ================================================================================
#
# ═════ 2 possible errors found ═════
# ┌ @ array.jl:809 Base.getindex(%1, 1)
# │ runtime dispatch detected: Base.getindex(%1::Array{Float64}, 1)
# └────────────────
# ┌ @ array.jl:809 Base.getindex(%1, %22)
# │ runtime dispatch detected: Base.getindex(%1::Array{Float64}, %22::Int64)
# └────────────────
#
# ================================================================================
#
# MethodInstance for sum(::Main.O.Foo)
#   from sum(foo::Main.O.Foo) in Main.O at In[4]:10
# Arguments
#   #self#::Core.Const(sum)
#   foo::Main.O.Foo
# Locals
#   @_3::Union{Nothing, Tuple{Float64, Int64}}
#   s::Float64
#   a::Array{Float64}
#   x::Float64
# Body::Float64
# 1 ─       (a = Base.getproperty(foo, :a))
# │   %2  = Main.O.eltype(a)::Core.Const(Float64)
# │         (s = Main.O.zero(%2))
# │   %4  = a::Array{Float64}
# │         (@_3 = Base.iterate(%4))
# │   %6  = (@_3 === nothing)::Bool
# │   %7  = Base.not_int(%6)::Bool
# └──       goto #4 if not %7
# 2 ┄ %9  = @_3::Tuple{Float64, Int64}
# │         (x = Core.getfield(%9, 1))
# │   %11 = Core.getfield(%9, 2)::Int64
# │         (s = s + x)
# │         (@_3 = Base.iterate(%4, %11))
# │   %14 = (@_3 === nothing)::Bool
# │   %15 = Base.not_int(%14)::Bool
# └──       goto #4 if not %15
# 3 ─       goto #2
# 4 ┄       return s
#
#
# ================================================================================
#
# check type-stabilities: Dispatch Test Failed at In[4]:35
#   Expression: #= In[4]:35 =# JETTest.@test_nodispatch sum(foo)
#   ═════ 2 possible errors found ═════
#   ┌ @ array.jl:809 Base.getindex(%1, 1)
#   │ runtime dispatch detected: Base.getindex(%1::Array{Float64}, 1)
#   └────────────────
#   ┌ @ array.jl:809 Base.getindex(%1, %22)
#   │ runtime dispatch detected: Base.getindex(%1::Array{Float64}, %22::Int64)
#   └────────────────
#
# Test Summary:          | Fail  Total
# check type-stabilities |    1      1
# WARNING: replacing module O.
# Some tests did not pass: 0 passed, 1 failed, 0 errored, 0 broken.
#
# Stacktrace:
#  [1] finish(ts::Test.DefaultTestSet)
#    @ Test C:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.8\Test\src\Test.jl:1044
#  [2] macro expansion
#    @ C:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.8\Test\src\Test.jl:1292 [inlined]
#  [3] top-level scope
#    @ .\In[4]:35
#  [4] eval
#    @ .\boot.jl:373 [inlined]
#  [5] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1196

# %%
using JETTest
using Test

module O

struct Foo
    a::Array{Float64}
end

function Base.sum(foo::Foo)
    a = foo.a
    s = zero(eltype(a))
    for x in a
        s += x
    end
    s
end

end

foo = O.Foo(randn(10^3))
@show sum(foo)

println("\n", "="^80, "\n")

@report_dispatch frame_filter = (sv -> sv.mod === @__MODULE__) sum(foo)

println("\n", "="^80, "\n")

@code_warntype sum(foo)

println("\n", "="^80, "\n")

@testset "check type-stabilities" begin
    @test_nodispatch frame_filter = (sv -> sv.mod === @__MODULE__) sum(foo)
end
# Out:
# sum(foo) = -40.104713445549336
#
# ================================================================================
#
# No errors !
#
# ================================================================================
#
# MethodInstance for sum(::Main.O.Foo)
#   from sum(foo::Main.O.Foo) in Main.O at In[5]:10
# Arguments
#   #self#::Core.Const(sum)
#   foo::Main.O.Foo
# Locals
#   @_3::Union{Nothing, Tuple{Float64, Int64}}
#   s::Float64
#   a::Array{Float64}
#   x::Float64
# Body::Float64
# 1 ─       (a = Base.getproperty(foo, :a))
# │   %2  = Main.O.eltype(a)::Core.Const(Float64)
# │         (s = Main.O.zero(%2))
# │   %4  = a::Array{Float64}
# │         (@_3 = Base.iterate(%4))
# │   %6  = (@_3 === nothing)::Bool
# │   %7  = Base.not_int(%6)::Bool
# └──       goto #4 if not %7
# 2 ┄ %9  = @_3::Tuple{Float64, Int64}
# │         (x = Core.getfield(%9, 1))
# │   %11 = Core.getfield(%9, 2)::Int64
# │         (s = s + x)
# │         (@_3 = Base.iterate(%4, %11))
# │   %14 = (@_3 === nothing)::Bool
# │   %15 = Base.not_int(%14)::Bool
# └──       goto #4 if not %15
# 3 ─       goto #2
# 4 ┄       return s
#
#
# ================================================================================
#
# Test Summary:          | Pass  Total
# check type-stabilities |    1      1
# WARNING: replacing module O.
# Test.DefaultTestSet("check type-stabilities", Any[], 1, false, false)

# %%
using JETTest
using Test

module O

struct Foo
    a::Vector{Float64}
end

function Base.sum(foo::Foo)
    a = foo.a
    s = zero(eltype(a))
    for x in a
        s += x
    end
    s
end

end

foo = O.Foo(randn(10^3))
@show sum(foo)

println("\n", "="^80, "\n")

@report_dispatch sum(foo)

println("\n", "="^80, "\n")

@code_warntype sum(foo)

println("\n", "="^80, "\n")

@testset "check type-stabilities" begin
    @test_nodispatch sum(foo)
end
# Out:
# sum(foo) = 33.97944567485137
#
# ================================================================================
#
# No errors !
#
# ================================================================================
#
# MethodInstance for sum(::Main.O.Foo)
#   from sum(foo::Main.O.Foo) in Main.O at In[6]:10
# Arguments
#   #self#::Core.Const(sum)
#   foo::Main.O.Foo
# Locals
#   @_3::Union{Nothing, Tuple{Float64, Int64}}
#   s::Float64
#   a::Vector{Float64}
#   x::Float64
# Body::Float64
# 1 ─       (a = Base.getproperty(foo, :a))
# │   %2  = Main.O.eltype(a)::Core.Const(Float64)
# │         (s = Main.O.zero(%2))
# │   %4  = a::Vector{Float64}
# │         (@_3 = Base.iterate(%4))
# │   %6  = (@_3 === nothing)::Bool
# │   %7  = Base.not_int(%6)::Bool
# └──       goto #4 if not %7
# 2 ┄ %9  = @_3::Tuple{Float64, Int64}
# │         (x = Core.getfield(%9, 1))
# │   %11 = Core.getfield(%9, 2)::Int64
# │         (s = s + x)
# │         (@_3 = Base.iterate(%4, %11))
# │   %14 = (@_3 === nothing)::Bool
# │   %15 = Base.not_int(%14)::Bool
# └──       goto #4 if not %15
# 3 ─       goto #2
# 4 ┄       return s
#
#
# ================================================================================
#
# Test Summary:          | Pass  Total
# check type-stabilities |    1      1
# WARNING: replacing module O.
# Test.DefaultTestSet("check type-stabilities", Any[], 1, false, false)
