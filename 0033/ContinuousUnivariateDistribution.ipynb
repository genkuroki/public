# %%
ENV["LINES"] = 100
using Distributions
using QuadGK

# %%
subtypes(ContinuousUnivariateDistribution)
# Out:
# 57-element Vector{Any}:
#  Arcsine
#  Beta
#  BetaPrime
#  Biweight
#  Cauchy
#  Chernoff
#  Chi
#  Chisq
#  Cosine
#  Distributions.Censored{D, Continuous, T} where {D<:(UnivariateDistribution), T<:Real}
#  Distributions.EdgeworthAbstract
#  Distributions.ReshapedDistribution{0, Continuous, D} where D<:(ContinuousDistribution{<:ArrayLikeVariate})
#  Epanechnikov
#  Erlang
#  Exponential
#  FDist
#  Frechet
#  Gamma
#  GeneralizedExtremeValue
#  GeneralizedPareto
#  Gumbel
#  InverseGamma
#  InverseGaussian
#  KSDist
#  KSOneSided
#  Kolmogorov
#  Laplace
#  Levy
#  LocationScale{T, Continuous, D} where {T<:Real, D<:Distribution{Univariate, Continuous}} (alias for Distributions.AffineDistribution{T, Continuous, D} where {T<:Real, D<:Distribution{ArrayLikeVariate{0}, Continuous}})
#  LogNormal
#  LogUniform
#  Logistic
#  LogitNormal
#  NoncentralBeta
#  NoncentralChisq
#  NoncentralF
#  NoncentralT
#  Normal
#  NormalCanon
#  NormalInverseGaussian
#  PGeneralizedGaussian
#  Pareto
# ...

# %%
methods(skewness)
# Out:
# # 57 methods for generic function "skewness":
# [1] skewness(d::SkewNormal) in Distributions at D:\.julia\packages\Distributions\O5xl5\src\univariate\continuous\skewnormal.jl:45
# [2] skewness(d::Pareto{T}) where T<:Real in Distributions at D:\.julia\packages\Distributions\O5xl5\src\univariate\continuous\pareto.jl:70
# [3] skewness(d::Logistic{T}) where T<:Real in Distributions at D:\.julia\packages\Distributions\O5xl5\src\univariate\continuous\logistic.jl:70
# [4] skewness(v::AbstractArray{T} where T<:Real) in StatsBase at D:\.julia\packages\StatsBase\pJqvO\src\moments.jl:317
# [5] skewness(v::AbstractArray{T} where T<:Real, m::Real) in StatsBase at D:\.julia\packages\StatsBase\pJqvO\src\moments.jl:281
# [6] skewness(v::AbstractArray{T} where T<:Real, wv::StatsBase.AbstractWeights) in StatsBase at D:\.julia\packages\StatsBase\pJqvO\src\moments.jl:318
# ...

# %%
?UnivariateMixture{Continuous}
# Out:
#   No documentation found.
#
#   Summary
#   ≡≡≡≡≡≡≡≡≡
#
#   abstract type AbstractMixtureModel{Univariate, S<:ValueSupport, C<:Distribution}
#
#   Subtypes
#   ≡≡≡≡≡≡≡≡≡≡
#
#   MixtureModel{Univariate, VS<:ValueSupport, C<:Distribution, CT<:(Categorical{P} where P<:Real)}
#   UnivariateGMM{VT1<:(AbstractVector{<:Real}), VT2<:(AbstractVector{<:Real}), C<:(Categorical{P} where P<:Real)}
#
#   Supertype Hierarchy
#   ≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡
#
#   AbstractMixtureModel{Univariate, S<:ValueSupport, C<:Distribution} <: Distribution{Univariate, S<:ValueSupport} <: Sampleable{Univariate, S<:ValueSupport} <: Any

# %%
?UnivariateDistribution
# Out:
# search: UnivariateDistribution DiscreteUnivariateDistribution
#   No documentation found.
#
#   Summary
#   ≡≡≡≡≡≡≡≡≡
#
#   abstract type Distribution{Univariate, S<:ValueSupport}
#
#   Subtypes
#   ≡≡≡≡≡≡≡≡≡≡
#
#   Arcsine{T<:Real}
#   Bernoulli{T<:Real}
#   Beta{T<:Real}
#   BetaBinomial{T<:Real}
#   BetaPrime{T<:Real}
#   Binomial{T<:Real}
#   Biweight{T<:Real}
#   Cauchy{T<:Real}
#   Chernoff
#   Chi{T<:Real}
#   Chisq{T<:Real}
#   Cosine{T<:Real}
#   Dirac{T}
#   DiscreteNonParametric{T<:Real, P<:Real, Ts<:AbstractArray{T<:Real, 1}, Ps<:AbstractArray{P<:Real, 1}}
#   DiscreteUniform
#   Distributions.AffineDistribution{T<:Real, S<:ValueSupport, D<:Distribution{Univariate, S<:ValueSupport}}
#   Distributions.Censored{D<:(UnivariateDistribution), S<:ValueSupport, T<:Real, TL<:Union{Nothing, T<:Real}, TU<:Union{Nothing, T<:Real}}
#   Distributions.EdgeworthAbstract
#   Distributions.ReshapedDistribution{0, S<:ValueSupport, D<:(Distribution{<:ArrayLikeVariate, S<:ValueSupport})}
# ...

# %%
subtypes(UnivariateDistribution)
# Out:
# 71-element Vector{Any}:
#  Arcsine
#  Bernoulli
#  Beta
#  BetaBinomial
#  BetaPrime
#  Binomial
#  Biweight
#  Cauchy
#  Chernoff
#  Chi
#  Chisq
#  Cosine
#  Dirac
#  DiscreteNonParametric
#  DiscreteUniform
#  Distributions.AffineDistribution
#  Distributions.Censored
#  Distributions.EdgeworthAbstract
#  Distributions.ReshapedDistribution{0, S, D} where {S<:ValueSupport, D<:(Distribution{<:ArrayLikeVariate, S})}
#  Epanechnikov
#  Erlang
#  Exponential
#  FDist
#  Frechet
#  Gamma
#  GeneralizedExtremeValue
#  GeneralizedPareto
#  Geometric
#  Gumbel
#  Hypergeometric
#  InverseGamma
#  InverseGaussian
#  KSDist
#  KSOneSided
#  Kolmogorov
#  Laplace
#  Levy
#  LogNormal
#  LogUniform
#  Logistic
#  LogitNormal
#  NegativeBinomial
#  NoncentralBeta
#  NoncentralChisq
#  NoncentralF
#  NoncentralHypergeometric
#  NoncentralT
#  Normal
#  NormalCanon
#  NormalInverseGaussian
#  PGeneralizedGaussian
#  Pareto
#  Poisson
#  PoissonBinomial
#  Rayleigh
#  Rician
#  Semicircle
# ...

# %%
?Soliton
# Out:
# search: Soliton
#   Soliton(K::Integer, M::Integer, δ::Real, atol::Real=0) <: Distribution{Univariate, Discrete}
#
#   The Robust Soliton distribution of length K, mode M (i.e., the location of
#   the robust component spike), peeling process failure probability δ, and
#   minimum non-zero probability mass atol. More specifically, degrees i for
#   which pdf(Ω, i)<atol are set to 0. Letting atol=0 yields the regular robust
#   Soliton distribution.
#
#   Soliton(K, M, δ)        # Robust Soliton distribution (with atol=0)
#   Soliton(K, M, δ, atol)  # Robust Soliton distribution with minimum non-zero probability mass atol
#
#   params(Ω)               # Get the parameters ,i.e., (K, M, δ, atol)
#   degrees(Ω)              # Return a vector composed of the degrees with non-zero probability mass
#   pdf(Ω, i)               # Evaluate the pdf at i
#   cdf(Ω, i)               # Evaluate the pdf at i
#   rand(Ω)                 # Sample from Ω
# ...
