# %%
using Distributions
using StatsPlots
default(fmt=:png)

apply(f, x...) = f(x...)
# Out:
# apply (generic function with 1 method)

# %%
dist(μ) = μ + TDist(3)

#n = 20
#X = rand(dist(0), n)
@show mean(X)
f(μ) = exp(loglikelihood(dist(μ), X) - loglikelihood(dist(0), X))
plot(f, -3, 3)
vline!([mean(X)])
# Out:
# mean(X) = -0.46896310365207006

# %%
dist(μ) = μ + TDist(3)

n = 10
X = rand(dist(0), n)
g(x) = exp(loglikelihood(dist(1), x .+ X) - loglikelihood(dist(0), x .+ X))
plot(g, -5, 25)

# %%
X
# Out:
# 10-element Vector{Float64}:
#   1.8783828833282916
#  -0.36146715533949325
#   0.5943506478440488
#   2.1860790433785846
#  -0.3644151676711409
#  -2.119385516121657
#   0.638137223573001
#  -0.5028885185466415
#  -6.480576340567433
#  -0.15784813639826048

# %%
@show X;
# Out:
# X = [1.8783828833282916, -0.36146715533949325, 0.5943506478440488, 2.1860790433785846, -0.3644151676711409, -2.119385516121657, 0.638137223573001, -0.5028885185466415, -6.480576340567433, -0.15784813639826048]

# %%
histogram(X)

# %%
@show round.(X; digits=1);
# Out:
# round.(X; digits = 1) = [1.9, -0.4, 0.6, 2.2, -0.4, -2.1, 0.6, -0.5, -6.5, -0.2]

# %%
Y = [1.88, -0.361, 0.594, 2.19, -0.364, -2.12, 0.638, -0.503, -6.48, -0.158]

@show mean(Y)
f(μ) = exp(loglikelihood(dist(μ), Y) - loglikelihood(dist(0), Y))
plot(f, -3, 3)
vline!([mean(Y)])
# Out:
# mean(Y) = -0.4684000000000001

# %%
dotplot(Y; size=(200, 400), xtick=1:1, xlim=(0.5, 1.5))
