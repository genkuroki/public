# %%
using Plots
pyplot(fontfamily = "IPAGothic")
# Out:
# Plots.PyPlotBackend()

# %%
plot(sin; label="正弦函数", title="正弦函数", xguide="x軸", yguide="y軸")

# %%
]st Plots PyPlot
# Out:
#       Status `D:\.julia\environments\v1.7\Project.toml`
#   [91a5bcdd] Plots v1.29.0
#   [d330b81b] PyPlot v2.10.0
