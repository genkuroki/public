# %%
X = randn(200, 2);

# %%
@time using GLMakie: GLMakie
# Out:
#   5.257840 seconds (13.26 M allocations: 915.908 MiB, 7.32% gc time, 8.51% compilation time)

# %%
@time GLMakie.scatter(X)
# Out:
#  29.537634 seconds (95.14 M allocations: 5.169 GiB, 4.38% gc time, 99.37% compilation time)
# FigureAxisPlot()

# %%
@time using CairoMakie: CairoMakie
# Out:
#   0.053899 seconds (95.83 k allocations: 4.120 MiB, 40.18% compilation time)

# %%
@time CairoMakie.scatter(X)
# Out:
#   0.086808 seconds (809.53 k allocations: 16.701 MiB, 38.09% gc time, 11.82% compilation time)
# FigureAxisPlot()
