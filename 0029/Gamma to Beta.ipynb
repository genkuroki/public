# %%
using Distributions
using StatsPlots

α, β = 10, 20
n = 10^6
X = rand(Gamma(α), n)
Y = rand(Gamma(β), n)
T = @. X / (X + Y)
histogram(T; norm=true, alpha=0.3, bin=100, label="X/(X+Y)")
plot!(Beta(α, β); label="Beta($α, $β)", lw=2)
