# %%
N <- 10^6
a <- 100
m <- 679
c <- 111
n <- 679
RR <- rbeta(N, 1+a, 1+m-a) / rbeta(N, 1+c, 1+n-c)
q <- quantile(RR, c(0.025, 0.5, 0.975))
print(q)
hist(RR, freq=F, breaks=50)
# Out:
#      2.5%       50%     97.5%
# 0.7034133 0.9017045 1.1539201
# Plot with title "Histogram of RR"

# %%
N <- 10^6
for (A in list(c(100, 679, 111, 679), c(95, 674, 107, 675), c(82, 624, 40, 288))) {
    a <- A[1]
    m <- A[2]
    c <- A[3]
    n <- A[4]
    RR <- rbeta(N, 1+a, 1+m-a) / rbeta(N, 1+c, 1+n-c)
    q <- quantile(RR, c(0.025, 0.5, 0.975))
    print(q)
    flush.console()
    hist(RR, freq=F, breaks=50)
}
# Out:
#      2.5%       50%     97.5%
# 0.7030405 0.9013826 1.1537114
#      2.5%       50%     97.5%
# 0.6889894 0.8901285 1.1470881
#      2.5%       50%     97.5%
# 0.6690131 0.9406802 1.3463005
# Plot with title "Histogram of RR"
# Plot with title "Histogram of RR"
# Plot with title "Histogram of RR"
