# %%
using StaticArrays
using Plots

function randrot(σ = 0.01)
    x, y, z = σ*randn(), σ*randn(), σ*randn()
    A = SMatrix{3, 3}(0, -z, y, z, 0, -x, -y, x, 0)
    exp(A)
end

function anim_randrot(L = 200, σ = 0.2)
    v = SVector(1.0, 0.0, 0.0)
    anim = @animate for _ in 1:L
        plot3d([0, v[1]], [0, v[2]], [0, v[3]]; label="", lw=3)
        plot!(xlim=(-1.1, 1.1), ylim=(-1.1, 1.1), zlim=(-1.1, 1.1))
        plot!(size=(500, 450))
        v = randrot(σ)*v
    end
    gif(anim, "randrot.gif")
end
# Out:
# anim_randrot (generic function with 3 methods)

# %%
U = randrot()
# Out:
# 3×3 SMatrix{3, 3, Float64, 9} with indices SOneTo(3)×SOneTo(3):
#   0.999959    0.00852014    0.0031813
#  -0.00851969  0.999964     -0.000153701
#  -0.0031825   0.000126591   0.999995

# %%
U'U
# Out:
# 3×3 SMatrix{3, 3, Float64, 9} with indices SOneTo(3)×SOneTo(3):
#  1.0           1.9112e-18    9.10377e-19
#  1.9112e-18    1.0          -3.44363e-20
#  9.10377e-19  -3.44363e-20   1.0

# %%
V = randrot(1)
# Out:
# 3×3 SMatrix{3, 3, Float64, 9} with indices SOneTo(3)×SOneTo(3):
#  0.014777   0.580539  -0.814099
#  0.357511   0.757297   0.546523
#  0.933792  -0.299125  -0.196358

# %%
V'V
# Out:
# 3×3 SMatrix{3, 3, Float64, 9} with indices SOneTo(3)×SOneTo(3):
#   1.0           1.27039e-16  -6.25331e-17
#   1.27039e-16   1.0          -3.57801e-16
#  -6.25331e-17  -3.57801e-16   1.0

# %%
anim_randrot()
# Out:
# [ Info: Saved animation to D:\OneDrive\public\0041\randrot.gif
# Plots.AnimatedGif("D:\\OneDrive\\public\\0041\\randrot.gif")
