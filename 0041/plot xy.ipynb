# %%
using Plots

# %%
f(x,y) = x^2 -y^2
x = y = range(-1, 1, 100)
surface(x, y, f; colorbar=false)

# %%
f(x,y) = x*y
x = y = range(-1, 1, 100)
surface(x, y, f; colorbar=false)

# %%
f(x,y) = x*y
x = y = range(-1, 1, 100)
surface(x, y, f; colorbar=false, camera=(75, 30))

# %%
using LinearAlgebra

# %%
A = [
    0 1 1
    1 0 1
    1 1 0
]
# Out:
# 3×3 Matrix{Int64}:
#  0  1  1
#  1  0  1
#  1  1  0

# %%
eigen(A)
# Out:
# Eigen{Float64, Float64, Matrix{Float64}, Vector{Float64}}
# values:
# 3-element Vector{Float64}:
#  -0.9999999999999999
#  -0.9999999999999982
#   1.9999999999999998
# vectors:
# 3×3 Matrix{Float64}:
#   0.707107  -0.408248  -0.57735
#  -0.707107  -0.408248  -0.57735
#   0.0        0.816497  -0.57735
