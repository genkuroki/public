# %% [markdown]
# https://twitter.com/sekai_tankyu/status/1500436256530235395
#
# ![FNKe0kkagAAqLbE.jpg](attachment:1a0185e8-9e2f-44d7-ae49-70ec2fa59d3a.jpg)

# %%
using Plots

t = range(0, 2π, 1000)
X = range(-1, 1, 1000)
plot(@.(3cos(t) + sin(t) + 5), @.(2cos(t) + sin(t) + 1); aspectratio=1,
    label="(3cos(t)+sin(t)+5, 2cos(t)+sin(t)+1)")
plot!(x -> 2/5*x, -1, 9; label="y = (2/5)x", ls=:dash)
plot!(x -> -2/3*x, -1, 9; label="y = (-2/3)x", ls=:dashdot)
#plot!(@.(3X + (4X+1)/7 + 5), @.(2X + (4X+1)/7 + 1);
#    label="(3X + (4X+1)/7 + 5, 2X + (4X+1)/7 + 1)", ls=:dot, lw=2)
plot!(x -> (18x - 64)/25, -1, 9; ls=:dot, lw=2,
    label="y = (18x - 64)/25")
plot!(; xlim=(-1, 9), ylim=(-2, 4), xtick=-1:9, ytick=-2:4, legend=:topleft)
