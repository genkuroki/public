# %%
using TraceFuns

# %%
@trace show("abc") Base.show
# Out:
# 0: show(abc) -- Method show(x) in Base at show.jl:393
#    1: show(IJulia.IJuliaStdio{Base.PipeEndpoint}(IOContext(Base.PipeEndpoint(Base.Libc.WindowsRawSocket(0x00000000000003a8) open, 0 bytes waiting))), abc) -- Method show(io::IO, s::AbstractString) in Base at strings/io.jl:193
# "abc"   1: show(IJulia.IJuliaStdio{Base.PipeEndpoint}(IOContext(Base.PipeEndpoint(Base.Libc.WindowsRawSocket(0x00000000000003a8) open, 0 bytes waiting))), abc) -> nothing
# 0: show(abc) -> nothing

# %%
@trace sin(10.0) :all
# Out:
# 0: sin(10.0) -- Method sin(x::T) where T<:Union{Float32, Float64} in Base.Math at special/trig.jl:29
#    1: abs(10.0) -- Method abs(x::Union{Float16, Float32, Float64}) in Base at float.jl:486
#        2: abs_float(10.0) -- Primitive abs_float
#        2: abs_float(10.0) -> 10.0
#    1: abs(10.0) -> 10.0
#    1: /(3.141592653589793, 4) -- Method /(x::Number, y::Number) in Base at promotion.jl:391
#        2: promote(3.141592653589793, 4) -- Method promote(x, y) in Base at promotion.jl:357
#            3: _promote(3.141592653589793, 4) -- Method _promote(x::T, y::S) where {T, S} in Base at promotion.jl:333
#                4: promote_type(Float64, Int64) -- Method promote_type(::Type{T}, ::Type{S}) where {T, S} in Base at promotion.jl:291
#                    5: promote_rule(Float64, Int64) -- Method promote_rule(::Type{Float64}, ::Type{Int64}) in Base at float.jl:147
#                    5: promote_rule(Float64, Int64) -> Float64
# ...

# %%
@trace sin(0.5) :all
# Out:
# 0: sin(0.5) -- Method sin(x::T) where T<:Union{Float32, Float64} in Base.Math at special/trig.jl:29
#    1: abs(0.5) -- Method abs(x::Union{Float16, Float32, Float64}) in Base at float.jl:486
#        2: abs_float(0.5) -- Primitive abs_float
#        2: abs_float(0.5) -> 0.5
#    1: abs(0.5) -> 0.5
#    1: /(3.141592653589793, 4) -- Method /(x::Number, y::Number) in Base at promotion.jl:391
#        2: promote(3.141592653589793, 4) -- Method promote(x, y) in Base at promotion.jl:357
#            3: _promote(3.141592653589793, 4) -- Method _promote(x::T, y::S) where {T, S} in Base at promotion.jl:333
#                4: promote_type(Float64, Int64) -- Method promote_type(::Type{T}, ::Type{S}) where {T, S} in Base at promotion.jl:291
#                    5: promote_rule(Float64, Int64) -- Method promote_rule(::Type{Float64}, ::Type{Int64}) in Base at float.jl:147
#                    5: promote_rule(Float64, Int64) -> Float64
# ...
