# %%
Integrate[f[x], {x,a,b}] // TeXForm
# Out:
# \int_a^b f(x) \, dx

# %%
A = {{0,-1},{1,0}};
A // TeXForm
# Out:
# \left(
# \begin{array}{cc}
#  0 & -1 \\
#  1 & 0 \\
# \end{array}
# \right)

# %%
MatrixExp[theta A] // TeXForm
# Out:
# \left(
# \begin{array}{cc}
#  \cos (\theta ) & -\sin (\theta ) \\
#  \sin (\theta ) & \cos (\theta ) \\
# \end{array}
# \right)

# %%
$Version // TeXForm
# Out:
# \text{13.1.0 for Microsoft Windows (64-bit) (June 16, 2022)}

# %%
Plot3D[Sin[x y], {x, -Pi, Pi}, {y, -Pi, Pi}]
# Out:
# -Graphics3D-

# %%
Integrate[Log[Sin[x]], x] // TeXForm
# Out:
# \frac{1}{2} i \left(x^2+\text{Li}_2\left(e^{2 i x}\right)\right)-x \log \left(1-e^{2 i\
#
# >   x}\right)+x \log (\sin (x))

# %%
pendulum = {y''[x] + Sin[y[x]] == 0, y[0] == 2, y'[0] == 1};
solpendulum = NDSolve[pendulum, y, {x, -10, 10}]
Plot[y[x] /. solpendulum, {x, -10, 10}]
Plot[Evaluate[{y[x], y'[x], y''[x]} /. solpendulum], {x, -10, 10}]
ParametricPlot[Evaluate[{y[x], y'[x]} /. solpendulum], {x, -10, 10}]
# Out:
# {{y -> InterpolatingFunction[{{-10., 10.}}, <>]}}
# -Graphics-
# -Graphics-
# -Graphics-

# %%
manipulatependulum = Manipulate[
    Module[
        {sol = NDSolve[{y''[x] + Sin[y[x]] == 0, y[0] == p[[1]], y'[0] == p[[2]]}, y, {x, 0, T}]},
        ParametricPlot[Evaluate[{y[x], y'[x]} /. sol], {x, 0, T}, PlotRange -> {{-2Pi, 2Pi}, {-3, 3}}]
    ], {{p, {2, 1}}, Locator}, {{T, 5}, 0, 20}
]
# Out:
# Manipulate[Module[{sol =
#
# >      NDSolve[{y''[x] + Sin[y[x]] == 0, y[0] == p[[1]], y'[0] == p[[2]]}, y, {x, 0, T}]}
#
# >     , ParametricPlot[Evaluate[{y[x], y'[x]} /. sol], {x, 0, T},
#
# >     PlotRange -> {{-2 Pi, 2 Pi}, {-3, 3}}]],
#
# >   {{p, {2, 1}}, Automatic, ControlType -> Locator}, {{T, 5}, 0, 20}]

# %%
Export["manipulatependulum.nb", manipulatependulum]
# Out:
# manipulatependulum.nb

# %%
ComplexPlot[(z^2+1)/(z^2-1), {z, -2-2 I, 2+ 2I}, ColorFunction->"CyclicLogAbsArg"]
# Out:
# -Graphics-

# %%
zetadata = Table[Zeta[0.6+t I], {t, 0, 100, 0.01}];
ComplexListPlot[zetadata]
# Out:
# -Graphics-

# %%
Graphics3D[Dodecahedron[]]
# Out:
# -Graphics3D-

# %%
ComplexListPlot[Eigenvalues[RandomVariate[NormalDistribution[], {1000, 1000}]/Sqrt[1000]]]
# Out:
# -Graphics-
