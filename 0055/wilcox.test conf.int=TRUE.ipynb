# %%
wilcox.test(c(1.1, 2.1, 3.1, 4.1), c(1.2, 2.5, 2.8, 3.0, 5.5), conf.int=TRUE)
# Out:
# 	Wilcoxon rank sum exact test
#
# data:  c(1.1, 2.1, 3.1, 4.1) and c(1.2, 2.5, 2.8, 3, 5.5)
# W = 9, p-value = 0.9048
# alternative hypothesis: true location shift is not equal to 0
# 95 percent confidence interval:
#  -3.4  1.9
# sample estimates:
# difference in location
#                  -0.25
