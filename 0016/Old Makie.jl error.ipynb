# %%
using CairoMakie, LaTeXStrings

xs = 0.0:0.01:2.0
lines(xs, sin.(π.*xs), axis=(title=L"\sin{x}",))
# Out:
# ArgumentError: regex matching is only available for the String type; use String(s) to convert
#
# Stacktrace:
#   [1] match(r::Regex, s::LaTeXString, i::Int64)
#     @ Base .\regex.jl:317
#   [2] match(r::Regex, s::LaTeXString)
#     @ Base .\regex.jl:316
#   [3] iswhitespace(str::LaTeXString)
#     @ Makie.MakieLayout D:\.julia\packages\Makie\c5WJV\src\makielayout\lineaxis.jl:412
#   [4] (::Makie.MakieLayout.var"#compute_protrusions#287"{Makie.Text{Tuple{String}}})(title::LaTeXString, titlesize::Float32, titlegap::Float32, titlevisible::Bool, spinewidth::Float32, topspinevisible::Bool, bottomspinevisible::Bool, leftspinevisible::Bool, rightspinevisible::Bool, xaxisprotrusion::Float32, yaxisprotrusion::Float32, xaxisposition::Symbol, yaxisposition::Symbol)
#     @ Makie.MakieLayout D:\.julia\packages\Makie\c5WJV\src\makielayout\layoutables\axis.jl:338
#   [5] (::Makie.MakieLayout.var"#257#288"{Makie.MakieLayout.var"#compute_protrusions#287"{Makie.Text{Tuple{String}}}, Observable{GridLayoutBase.RectSides{Float32}}})(::LaTeXString, ::Vararg{Any, N} where N)
#     @ Makie.MakieLayout D:\.julia\packages\Makie\c5WJV\src\makielayout\layoutables\axis.jl:357
#   [6] (::Observables.OnUpdate{Makie.MakieLayout.var"#257#288"{Makie.MakieLayout.var"#compute_protrusions#287"{Makie.Text{Tuple{String}}}, Observable{GridLayoutBase.RectSides{Float32}}}, Tuple{Observable{Any}, Observable{Any}, Observable{Any}, Observable{Any}, Observable{Any}, Observable{Any}, Observable{Any}, Observable{Any}, Observable{Any}, Observable{Float32}, Observable{Float32}, Observable{Any}, Observable{Any}}})(#unused#::LaTeXString)
#     @ Observables D:\.julia\packages\Observables\Yf3xU\src\Observables.jl:298
#   [7] setindex!(observable::Observable{Any}, val::LaTeXString; notify::Observables.var"#9#11")
#     @ Observables D:\.julia\packages\Observables\Yf3xU\src\Observables.jl:205
#   [8] setindex!(observable::Observable{Any}, val::LaTeXString)
#     @ Observables D:\.julia\packages\Observables\Yf3xU\src\Observables.jl:201
#   [9] layoutable(::Type{Axis}, fig_or_scene::Figure; bbox::Nothing, kwargs::Base.Iterators.Pairs{Symbol, LaTeXString, Tuple{Symbol}, NamedTuple{(:title,), Tuple{LaTeXString}}})
#     @ Makie.MakieLayout D:\.julia\packages\Makie\c5WJV\src\makielayout\layoutables\axis.jl:361
#  [10] #_layoutable#11
#     @ D:\.julia\packages\Makie\c5WJV\src\makielayout\layoutables.jl:63 [inlined]
#  [11] #_#9
#     @ D:\.julia\packages\Makie\c5WJV\src\makielayout\layoutables.jl:49 [inlined]
#  [12] plot(::Type{Lines{ArgType} where ArgType}, ::StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}}, ::Vararg{Any, N} where N; axis::NamedTuple{(:title,), Tuple{LaTeXString}}, figure::NamedTuple{(), Tuple{}}, kw_attributes::Base.Iterators.Pairs{Union{}, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ Makie D:\.julia\packages\Makie\c5WJV\src\figureplotting.jl:31
#  [13] lines(::StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}}, ::Vararg{Any, N} where N; attributes::Base.Iterators.Pairs{Symbol, NamedTuple{(:title,), Tuple{LaTeXString}}, Tuple{Symbol}, NamedTuple{(:axis,), Tuple{NamedTuple{(:title,), Tuple{LaTeXString}}}}})
#     @ Makie D:\.julia\packages\Makie\c5WJV\src\recipes.jl:15
#  [14] top-level scope
#     @ In[1]:4
#  [15] eval
#     @ .\boot.jl:360 [inlined]
#  [16] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base .\loading.jl:1116

# %%
using Pkg
println("Julia v", VERSION)
Pkg.status("CairoMakie")
Pkg.status("Makie"; mode=PKGMODE_MANIFEST)
Pkg.status("LaTeXStrings")
# Out:
# Julia v1.6.2
#       Status `D:\.julia\environments\v1.6\Project.toml`
#   [13f3f980] CairoMakie v0.5.10
#       Status `D:\.julia\environments\v1.6\Manifest.toml`
#   [ee78f7c6] Makie v0.13.14
#       Status `D:\.julia\environments\v1.6\Project.toml`
#   [b964fa9f] LaTeXStrings v1.2.1

# %%
using CairoMakie, LaTeXStrings

xs = 0.0:0.01:2.0
lines(xs, sin.(π.*xs), axis=(title=L"\sin{x}",))
# Out:
# FigureAxisPlot()

# %%
using Pkg
println("Julia v", VERSION)
Pkg.status("CairoMakie")
Pkg.status("Makie"; mode=PKGMODE_MANIFEST)
Pkg.status("LaTeXStrings")
# Out:
# Julia v1.8.0-DEV.310
#       Status `D:\.julia\environments\v1.8\Project.toml`
#   [13f3f980] CairoMakie v0.6.3
#       Status `D:\.julia\environments\v1.8\Manifest.toml`
#   [ee78f7c6] Makie v0.15.0
#       Status `D:\.julia\environments\v1.8\Project.toml`
#   [b964fa9f] LaTeXStrings v1.2.1

# %%
]add CairoMakie LaTeXStrings
# Out:
#     Updating registry at `D:\.julia\registries\General`
#     Updating git-repo `https://github.com/JuliaRegistries/General.git`
#    Resolving package versions...
#    Installed CairoMakie ─ v0.5.10
#    Installed Makie ────── v0.13.14
#     Updating `D:\.julia\environments\v1.6\Project.toml`
#   [13f3f980] + CairoMakie v0.5.10
#     Updating `D:\.julia\environments\v1.6\Manifest.toml`
#   [27a7e980] + Animations v0.4.1
#   [159f3aea] + Cairo v1.0.5
#   [13f3f980] + CairoMakie v0.5.10
#   [a2cac450] + ColorBrewer v0.4.0
#   [c3611d14] + ColorVectorSpace v0.9.5
#   [34da2185] ↑ Compat v3.33.0 ⇒ v3.34.0
#   [1a297f60] ↑ FillArrays v0.12.1 ⇒ v0.12.2
#   [b38be410] + FreeType v4.0.0
#   [663a7486] + FreeTypeAbstraction v0.9.1
#   [5c1252a2] ↓ GeometryBasics v0.4.1 ⇒ v0.3.12
#   [a2bd30eb] + Graphics v1.1.0
#   [3955a311] + GridLayoutBase v0.5.7
#   [a09fc81d] + ImageCore v0.9.1
#   [82e4d734] + ImageIO v0.5.7
#   [f1662d9f] + Isoband v0.1.1
#   [ee78f7c6] + Makie v0.13.14
#   [dbb5928d] + MappedArrays v0.4.1
#   [7eb4fadd] + Match v1.1.0
#   [e94cdb99] + MosaicViews v0.3.3
#   [f09324ee] + Netpbm v1.0.2
#   [52e1d378] + OpenEXR v0.3.2
#   [1dea7af3] ↑ OrdinaryDiffEq v5.63.1 ⇒ v5.63.2
#   [f57f5aa1] + PNGFiles v0.3.7
#   [19eb6ba3] + Packing v0.4.1
#   [5432bcbf] + PaddedViews v0.5.10
#   [eebad327] + PkgVersion v0.1.1
#   [647866c9] + PolygonOps v0.1.1
#   [92933f4c] + ProgressMeter v1.7.1
#   [73760f76] + SignedDistanceFields v0.4.0
#   [cae243ae] + StackViews v0.1.1
#   [09ab397b] ↓ StructArrays v0.6.0 ⇒ v0.5.1
#   [62fd8b95] + TensorCore v0.1.1
#   [731e570b] + TiffImages v0.4.1
#   [1cfade01] + UnicodeFun v0.4.1
#   [3b182d85] + Graphite2_jll v1.3.14+0
#   [2e76f6c2] + HarfBuzz_jll v2.8.1+0
#   [905a6f67] + Imath_jll v3.1.2+0
#   [18a262bb] + OpenEXR_jll v3.1.1+0
#   [36c8627f] + Pango_jll v1.42.4+10
#   [9a68df92] + isoband_jll v0.2.2+0
# Precompiling project...
#   ✓ Match
#   ✓ PolygonOps
#   ✓ SignedDistanceFields
#   ✓ MappedArrays
#   ✓ PkgVersion
#   ✓ ProgressMeter
#   ✓ isoband_jll
#   ✓ TensorCore
#   ✓ StackViews
#   ✓ PaddedViews
#   ✓ UnicodeFun
#   ✓ Compat
#   ✓ FillArrays
#   ✓ Graphite2_jll
#   ✓ StructArrays
#   ✓ Imath_jll
#   ✓ FreeType
#   ✓ Graphics
#   ✓ Animations
#   ✓ Isoband
#   ✓ MosaicViews
#   ✓ ChainRulesCore
#   ✓ HarfBuzz_jll
#   ✓ DataStructures
#   ✓ OpenEXR_jll
#   ✓ ColorBrewer
#   ✓ ArrayLayouts
#   ✓ Pango_jll
#   ✓ QuadGK
#   ✓ Interpolations
#   ✓ SortingAlgorithms
#   ✓ SpecialFunctions
#   ✓ RecursiveArrayTools
#   ✓ MultivariatePolynomials
#   ✓ OpenEXR
#   ✓ GeometryBasics
#   ✓ Vega
#   ✓ Cairo
#   ✓ JuliaFormatter
#   ✓ DiffRules
#   ✓ BandedMatrices
#   ✓ LightGraphs
#   ✓ StatsBase
#   ✓ StatsFuns
#   ✓ DynamicPolynomials
#   ✓ ColorVectorSpace
#   ✓ Packing
#   ✓ TiffImages
#   ✓ SciMLBase
#   ✓ SymPy
#   ✓ VertexSafeGraphs
#   ✓ ForwardDiff
#   ✓ Clustering
#   ✓ MultivariateStats
#   ✓ VegaLite
#   ✓ StatsModels
#   ✓ GridLayoutBase
#   ✓ Distributions
#   ✓ DEDataArrays
#   ✓ FreeTypeAbstraction
#   ✓ SparseDiffTools
#   ✓ NLSolversBase
#   ✓ PreallocationTools
#   ✓ ProfileVega
#   ✓ NonlinearSolve
#   ✓ KernelDensity
#   ✓ MonteCarloMeasurements
#   ✓ LineSearches
#   ✓ SymbolicUtils
#   ✓ NLsolve
#   ✓ Optim
#   ✓ DataFrames
#   ✓ RCall
#   ✓ ScikitLearn
#   ✓ DiffEqBase
#   ✓ ImageCore
#   ✓ BoundaryValueDiffEq
#   ✓ DiffEqJump
#   ✓ DiffEqNoiseProcess
#   ✓ Symbolics
#   ✓ Netpbm
#   ✓ Sundials
#   ✓ PNGFiles
#   ✓ ImageIO
#   ✓ Plots
#   ✓ DiffEqFinancial
#   ✓ StatsPlots
#   ✓ Makie
#   ✓ CairoMakie
#   ✓ OrdinaryDiffEq
#   ✓ DelayDiffEq
#   ✓ DiffEqCallbacks
#   ✓ StochasticDiffEq
#   ✓ DiffEqPhysics
#   ✓ SteadyStateDiffEq
#   ✓ MultiScaleArrays
#   ✓ ModelingToolkit
#   ✓ ParameterizedFunctions
#   ✓ DifferentialEquations
#   99 dependencies successfully precompiled in 185 seconds (269 already precompiled)
