# %%
using Distributions
using StatsPlots
using QuadGK
default(fmt=:png)

# %%
function plot_logFDist(m, n;
        fdist = FDist(m, n),
        xlim = log.(quantile.(fdist, (0.00001, 0.99999))))
    f(t) = pdf(fdist, exp(t))*exp(t)
    logf(t) = logpdf(fdist, exp(t)) + t
    μ = quadgk(t -> t*f(t), xlim...)[1]
    σ² = quadgk(t -> (t - μ)^2*f(t), xlim...)[1]
    @show normal = Normal(μ, √σ²)
    plot(f ; label="log FDist($m, $n)", xlim)
    plot!(normal; label="normal approx", ls=:dash)
    if n > 4
        @show μf, σf = mean(fdist), std(fdist)
        @show normal_delta = Normal(log(μf) - σf^2/(2μf), σf/μf)
        plot!(normal_delta; label="delta method", ls=:dashdot)
    end
    plot!()
end
# Out:
# plot_logFDist (generic function with 1 method)

# %%
plot_logFDist(3, 1.5)
# Out:
# normal = Normal(μ, √σ²) = Normal{Float64}(μ=0.4291272921045245, σ=1.863665383640553)

# %%
plot_logFDist(10, 5)
# Out:
# normal = Normal(μ, √σ²) = Normal{Float64}(μ=0.10979436838082632, σ=0.8433512200056525)
# (μf, σf) = (mean(fdist), std(fdist)) = (1.6666666666666667, 2.6874192494328497)
# normal_delta = Normal(log(μf) - σf ^ 2 / (2μf), σf / μf) = Normal{Float64}(μ=-1.6558410429006758, σ=1.6124515496597098)

# %%
plot_logFDist(30, 15)
# Out:
# normal = Normal(μ, √σ²) = Normal{Float64}(μ=0.03443645626163507, σ=0.4598419226246886)
# (μf, σf) = (mean(fdist), std(fdist)) = (1.1538461538461537, 0.5890337270276772)
# normal_delta = Normal(log(μf) - σf ^ 2 / (2μf), σf / μf) = Normal{Float64}(μ=-0.007248806708977096, σ=0.5104958967573203)

# %%
plot_logFDist(100, 50)
# Out:
# normal = Normal(μ, √σ²) = Normal{Float64}(μ=0.010098447985529866, σ=0.24695397927566615)
# (μf, σf) = (mean(fdist), std(fdist)) = (1.0416666666666667, 0.2642382635111381)
# normal_delta = Normal(log(μf) - σf ^ 2 / (2μf), σf / μf) = Normal{Float64}(μ=0.007307501766632009, σ=0.2536687329706926)

# %%
plot_logFDist(300, 150)
# Out:
# normal = Normal(μ, √σ²) = Normal{Float64}(μ=0.003343946505298328, σ=0.14178624840052534)
# (μf, σf) = (mean(fdist), std(fdist)) = (1.0135135135135136, 0.1449594368785775)
# normal_delta = Normal(log(μf) - σf ^ 2 / (2μf), σf / μf) = Normal{Float64}(μ=0.003056489417664652, σ=0.14302664438686313)
