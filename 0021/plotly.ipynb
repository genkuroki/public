# %%
using Plots
default(size=(500, 350), legend=false)

# %%
plotlyjs()
plot(rand(10))
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-5037749045842595371\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-13984742881281946478\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio-jupyter-notebook\"]) {\n            // Extension already loaded.\n   
# ...

# %%
plotly()
plot(rand(10))

# %%
]st PlotlyJS
# Out:
#       Status `D:\.julia\environments\v1.6\Project.toml`
#   [f0f68f2c] PlotlyJS v0.14.1

# %%
]st -m WebIO
# Out:
#       Status `D:\.julia\environments\v1.6\Manifest.toml`
#   [0f1e0344] WebIO v0.8.15
