# %% [markdown]
# https://x.com/f_sei/status/1805078679082676617

# %%
using Plots

f(x) = sin(x)
g(x) = 4/π*x - 4/π^2*x^2

plot(f, -0.1π, 1.1π)
plot!(g)

# %%
plot(x -> g(x) - f(x), 0, π)

# %%
plot(f, 0.4π, 0.6π)
plot!(g)
